# %%
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as Models
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, average_precision_score
from tqdm import tqdm

RandomState = 2022484
np.random.seed(RandomState)
random.seed(RandomState)
torch.manual_seed(RandomState)
Device = torch.device("cuda")

def LoadMetaFromDirectory(DataDir):
    MetaData = []
    for MajorCategory in os.listdir(DataDir):
        MajorPath = os.path.join(DataDir, MajorCategory)
        if os.path.isdir(MajorPath):
            for ClassName in os.listdir(MajorPath):
                ClassPath = os.path.join(MajorPath, ClassName)
                if os.path.isdir(ClassPath):
                    for FileName in os.listdir(ClassPath):
                        if FileName.endswith(".wav"):
                            MetaData.append({
                                "filename": FileName,
                                "major_category": MajorCategory,
                                "class_name": ClassName,
                                "file_path": os.path.join(ClassPath, FileName)
                            })
    return pd.DataFrame(MetaData)

def PlotClassDistribution(MetaDf):
    plt.figure(figsize=(12, 5))
    sns.countplot(data=MetaDf, x="class_name", order=MetaDf["class_name"].value_counts().index)
    plt.title("Class Distribution in ESC-50")
    plt.xticks(rotation=90)
    plt.xlabel("Class Name")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

def PlotMajorCategoryDistribution(MetaDf):
    plt.figure(figsize=(7, 5))
    sns.countplot(data=MetaDf, x="major_category")
    plt.title("Major Category Distribution in ESC-50")
    plt.xticks(rotation=45)
    plt.xlabel("Major Category")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

def DisplayRandomAudios(MetaDf, NumSamples=6):
    RandomFiles = MetaDf.sample(NumSamples, random_state=RandomState)
    Fig, Axes = plt.subplots(2, NumSamples, figsize=(22, 8))
    
    for i, (_, Row) in enumerate(RandomFiles.iterrows()):
        FilePath = Row["file_path"]
        FileName = Row["filename"]
        ClassName = Row["class_name"]
        MajorCategory = Row["major_category"]

        Signal, Sr = librosa.load(FilePath, sr=None)
        MelSpec = librosa.feature.melspectrogram(
            y=Signal, sr=Sr, n_fft=2048, hop_length=512, n_mels=128
        )
        MelSpecDb = librosa.power_to_db(MelSpec, ref=np.max)

        Axes[0, i].plot(np.linspace(0, len(Signal) / Sr, len(Signal)), Signal, color="b")
        Axes[0, i].set_title(f"{FileName}\n{ClassName} ({MajorCategory})", fontsize=9)
        Axes[0, i].axis("tight")

        Img = librosa.display.specshow(
            MelSpecDb, sr=Sr, hop_length=512, x_axis="time", y_axis="mel",
            cmap="viridis", ax=Axes[1, i]
        )
        Axes[1, i].set_title("Mel Spectrogram", fontsize=9)
        if i == NumSamples - 1:
            Fig.colorbar(Img, ax=Axes[1, i], format="%+2.0f dB")

    plt.tight_layout()
    plt.show()

def SplitTrainValTest(MetaDf, ValRatio=0.1, TestRatio=0.1):
    TrainRatio = 1.0 - (ValRatio + TestRatio)
    TrainDf, TempDf = train_test_split(
        MetaDf,
        test_size=(1 - TrainRatio),
        stratify=MetaDf["class_name"],
        random_state=RandomState
    )
    RelativeValRatio = ValRatio / (ValRatio + TestRatio)
    ValDf, TestDf = train_test_split(
        TempDf,
        test_size=(1 - RelativeValRatio),
        stratify=TempDf["class_name"],
        random_state=RandomState
    )
    return TrainDf, ValDf, TestDf

def FixedCountSplit(TrainDf, XPerClass):
    LabeledList = []
    UnlabeledList = []
    Grouped = TrainDf.groupby("class_name")
    for Cname, GroupDf in Grouped:
        GroupList = GroupDf.sample(frac=1, random_state=RandomState).values.tolist()
        if len(GroupList) <= XPerClass:
            LabeledList.extend(GroupList)
        else:
            LabeledList.extend(GroupList[:XPerClass])
            UnlabeledList.extend(GroupList[XPerClass:])
    LabeledCols = TrainDf.columns.tolist()
    UnlabeledCols = TrainDf.columns.tolist()

    LabeledDf = pd.DataFrame(LabeledList, columns=LabeledCols)
    UnlabeledDf = pd.DataFrame(UnlabeledList, columns=UnlabeledCols)
    return LabeledDf, UnlabeledDf

def AddGaussianNoise(Signal, NoiseFactor=0.05):
    Noise = np.random.normal(0, 1, len(Signal))
    return Signal + NoiseFactor * Noise

def PitchChange(Signal, Sr, PitchRange=5):
    PitchSteps = np.random.uniform(-PitchRange, PitchRange)
    return librosa.effects.pitch_shift(Signal, sr=Sr, n_steps=PitchSteps)

def SpecAugment(MelSpec, TimeMaskParam=20, FreqMaskParam=10):
    MelSpecAug = MelSpec.copy()
    if MelSpecAug.shape[1] > TimeMaskParam:
        T0 = np.random.randint(0, MelSpecAug.shape[1] - TimeMaskParam)
        MelSpecAug[:, T0:T0 + TimeMaskParam] = 0
    if MelSpecAug.shape[0] > FreqMaskParam:
        F0 = np.random.randint(0, MelSpecAug.shape[0] - FreqMaskParam)
        MelSpecAug[F0:F0 + FreqMaskParam, :] = 0
    return MelSpecAug

def Cutout(MelSpec, NumHoles=8, HoleSize=(5, 5)):
    MelSpecAug = MelSpec.copy()
    H, W = MelSpec.shape
    for _ in range(NumHoles):
        Y = np.random.randint(0, H - HoleSize[0])
        X = np.random.randint(0, W - HoleSize[1])
        MelSpecAug[Y:Y + HoleSize[0], X:X + HoleSize[1]] = 0
    return MelSpecAug

def AudioWeakAugmentation(Signal, Sr):
    TransformType = random.choice(["noise", "pitch_shift"])
    if TransformType == "noise":
        Signal = AddGaussianNoise(Signal, NoiseFactor=0.02)
    else:
        Signal = PitchChange(Signal, Sr, PitchRange=2)
    MelSpec = librosa.feature.melspectrogram(
        y=Signal, sr=Sr, n_fft=2048, hop_length=512, n_mels=128
    )
    MelSpecDb = librosa.power_to_db(MelSpec, ref=np.max)
    return MelSpecDb

def AudioStrongAugmentation(Signal, Sr):
    TransformType = random.choice(["big_pitch_shift", "heavy_noise"])
    if TransformType == "big_pitch_shift":
        Signal = PitchChange(Signal, Sr, PitchRange=5)
    else:
        Signal = AddGaussianNoise(Signal, NoiseFactor=0.05)

    MelSpec = librosa.feature.melspectrogram(
        y=Signal, sr=Sr, n_fft=2048, hop_length=512, n_mels=128
    )
    MelSpecDb = librosa.power_to_db(MelSpec, ref=np.max)

    SpecTransform = random.choice(["spec_augment", "cutout"])
    if SpecTransform == "spec_augment":
        MelSpecDb = SpecAugment(MelSpecDb, TimeMaskParam=25, FreqMaskParam=12)
    else:
        MelSpecDb = Cutout(MelSpecDb, NumHoles=10, HoleSize=(5, 5))

    return MelSpecDb

class AudioReFixMatchDataset(Dataset):
    def __init__(self, Df, IsUnlabeled=False):
        super().__init__()
        self.Df = Df.reset_index(drop=True)
        self.IsUnlabeled = IsUnlabeled
        self.Classes = sorted(Df["class_name"].unique())  
        self.ClassToIdx = {Cname: Idx for Idx, Cname in enumerate(self.Classes)}

    def __len__(self):
        return len(self.Df)

    def __getitem__(self, Idx):
        Row = self.Df.iloc[Idx]
        FilePath = Row["file_path"]
        ClassName = Row["class_name"]
        Label = self.ClassToIdx[ClassName]

        Signal, Sr = librosa.load(FilePath, sr=None)

        MelSpecOrig = librosa.feature.melspectrogram(
            y=Signal, sr=Sr, n_fft=2048, hop_length=512, n_mels=128
        )
        MelSpecOrigDb = librosa.power_to_db(MelSpecOrig, ref=np.max)

        MelSpecWeakDb = AudioWeakAugmentation(Signal, Sr)

        MelSpecStrongDb = AudioStrongAugmentation(Signal, Sr)

        OrigTensor = torch.tensor(MelSpecOrigDb, dtype=torch.float).unsqueeze(0)
        WeakTensor = torch.tensor(MelSpecWeakDb, dtype=torch.float).unsqueeze(0)
        StrongTensor = torch.tensor(MelSpecStrongDb, dtype=torch.float).unsqueeze(0)

        if self.IsUnlabeled:
            return {
                "Original": OrigTensor,
                "Weak": WeakTensor,
                "Strong": StrongTensor,
                "Label": -1
            }
        else:
            return {
                "Original": OrigTensor,
                "Weak": WeakTensor,
                "Strong": StrongTensor,
                "Label": Label
            }

class AudioTestDataset(Dataset):
    def __init__(self, Df):
        super().__init__()
        self.Df = Df.reset_index(drop=True)
        self.Classes = sorted(Df["class_name"].unique())
        self.ClassToIdx = {Cname: Idx for Idx, Cname in enumerate(self.Classes)}

    def __len__(self):
        return len(self.Df)

    def __getitem__(self, Idx):
        Row = self.Df.iloc[Idx]
        FilePath = Row["file_path"]
        ClassName = Row["class_name"]
        Label = self.ClassToIdx[ClassName]

        Signal, Sr = librosa.load(FilePath, sr=None)
        MelSpec = librosa.feature.melspectrogram(
            y=Signal, sr=Sr, n_fft=2048, hop_length=512, n_mels=128
        )
        MelSpecDb = librosa.power_to_db(MelSpec, ref=np.max)

        MelTensor = torch.tensor(MelSpecDb, dtype=torch.float).unsqueeze(0)
        return MelTensor, Label

class AudioDenseNet(nn.Module):
    def __init__(self, NumClasses=50):
        super().__init__()
        self.Backbone = Models.densenet121(weights=Models.DenseNet121_Weights.DEFAULT)
        self.Backbone.features.conv0 = nn.Conv2d(
            in_channels=1,
            out_channels=64,
            kernel_size=7,
            stride=2,
            padding=3,
            bias=False
        )
        nn.init.kaiming_normal_(self.Backbone.features.conv0.weight, mode='fan_out', nonlinearity='relu')

        NumFeats = self.Backbone.classifier.in_features
        self.Backbone.classifier = nn.Linear(NumFeats, NumClasses)

    def forward(self, X):
        return self.Backbone(X)

def TrainFixMatchAudio(
    Model,
    LabeledLoader,
    UnlabeledLoader,
    ValLoader,
    TestLoader,
    RealClassNames,    
    NumEpochs=20,
    Lr=0.01,
    Tau=0.95,
    LambdaU=0.8,
    Eps=1e-8,
    RunName="Run"
):
    NumClasses = len(RealClassNames)
    Optimizer = torch.optim.SGD(Model.parameters(), lr=Lr, momentum=0.9, weight_decay=1e-4)
    Scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(Optimizer, T_max=NumEpochs)
    Model = Model.to(Device)

    TrainLossList = []
    TrainSupLossList = []
    TrainUnsupLossList = []
    TrainAccList = []
    ValLossList = []
    ValAccList = []

    for Epoch in range(NumEpochs):
        Model.train()
        TotalLoss = 0.0
        SupLossTotal = 0.0
        UnsupLossTotal = 0.0
        CorrectSup = 0
        TotalSup = 0
        BatchCount = 0

        UnlabeledIter = iter(UnlabeledLoader)

        for LabeledBatch in tqdm(LabeledLoader, desc=f"{RunName} - Epoch {Epoch+1}/{NumEpochs}", leave=False):
            InputsLWeak = LabeledBatch["Weak"].float().to(Device)
            LabelsL = LabeledBatch["Label"].to(Device).long()
            LogitsL = Model(InputsLWeak)
            LossSup = F.cross_entropy(LogitsL, LabelsL)

            PredsL = torch.argmax(LogitsL, dim=1)
            CorrectSup += (PredsL == LabelsL).sum().item()
            TotalSup += LabelsL.size(0)

            try:
                UnlabeledBatch = next(UnlabeledIter)
            except StopIteration:
                UnlabeledIter = iter(UnlabeledLoader)
                UnlabeledBatch = next(UnlabeledIter)

            InputsUWeak = UnlabeledBatch["Weak"].float().to(Device)
            InputsUStrong = UnlabeledBatch["Strong"].float().to(Device)

            with torch.no_grad():
                LogitsUWeak = Model(InputsUWeak)
                ProbsUWeak = F.softmax(LogitsUWeak, dim=1)

            MaxProbs, PseudoLabels = torch.max(ProbsUWeak, dim=1)
            Mask = (MaxProbs >= Tau).float()

            LogitsUStrong = Model(InputsUStrong)
            LossUCe = F.cross_entropy(LogitsUStrong, PseudoLabels, reduction="none")
            LossUCe = (LossUCe * Mask).mean()

            LossUnsup = LossUCe

            Loss = LossSup + LambdaU * LossUnsup

            Optimizer.zero_grad()
            Loss.backward()
            torch.nn.utils.clip_grad_norm_(Model.parameters(), max_norm=5.0)
            Optimizer.step()

            TotalLoss += Loss.item()
            SupLossTotal += LossSup.item()
            UnsupLossTotal += LossUnsup.item()
            BatchCount += 1

        AvgLoss = TotalLoss / BatchCount
        AvgSupLoss = SupLossTotal / BatchCount
        AvgUnsupLoss = UnsupLossTotal / BatchCount
        TrainAcc = CorrectSup / TotalSup

        TrainLossList.append(AvgLoss)
        TrainSupLossList.append(AvgSupLoss)
        TrainUnsupLossList.append(AvgUnsupLoss)
        TrainAccList.append(TrainAcc)

        Model.eval()
        ValLossVal = 0.0
        ValBatches = 0
        ValPreds = []
        ValLabelsList = []
        with torch.no_grad():
            for ValInput, ValLabels in ValLoader:
                ValInput = ValInput.float().to(Device)
                ValLabels = ValLabels.to(Device)
                LogitsVal = Model(ValInput)
                LossVal = F.cross_entropy(LogitsVal, ValLabels)
                ValLossVal += LossVal.item()
                ValBatches += 1
                Preds = torch.argmax(LogitsVal, dim=1)
                ValPreds.extend(Preds.cpu().numpy())
                ValLabelsList.extend(ValLabels.cpu().numpy())

        AvgValLoss = ValLossVal / ValBatches
        ValAccuracy = accuracy_score(ValLabelsList, ValPreds)
        ValLossList.append(AvgValLoss)
        ValAccList.append(ValAccuracy)

        print(f"{RunName} [Epoch {Epoch+1}/{NumEpochs}] "
              f"TrainLoss: {AvgLoss:.4f} (Sup={AvgSupLoss:.4f}, Unsup={AvgUnsupLoss:.4f}), "
              f"TrainAcc: {TrainAcc*100:.2f}% | "
              f"ValLoss: {AvgValLoss:.4f}, ValAcc: {ValAccuracy*100:.2f}%")

        Scheduler.step()

    TestPreds = []
    TestLabelsList = []
    TestProbsList = []
    Model.eval()
    with torch.no_grad():
        for TestInput, TestLabels in TestLoader:
            TestInput = TestInput.float().to(Device)
            TestLabels = TestLabels.to(Device)
            LogitsTest = Model(TestInput)
            ProbsTest = F.softmax(LogitsTest, dim=1)
            PredsTest = torch.argmax(LogitsTest, dim=1)

            TestPreds.extend(PredsTest.cpu().numpy())
            TestLabelsList.extend(TestLabels.cpu().numpy())
            TestProbsList.extend(ProbsTest.cpu().numpy())

    TestAcc = accuracy_score(TestLabelsList, TestPreds)
    OneHotTestLabels = np.eye(NumClasses)[np.array(TestLabelsList)]
    RocAuc = roc_auc_score(OneHotTestLabels, np.array(TestProbsList), multi_class="ovr")
    AvgPrecision = average_precision_score(OneHotTestLabels, np.array(TestProbsList), average="macro")

    print(f"\n{RunName} --- Final Test Results ---")
    print(f"Test Accuracy: {TestAcc*100:.2f}%")
    print(f"ROC AUC: {RocAuc:.4f}, Average Precision (AUC-PRC): {AvgPrecision:.4f}")

    print("\nClassification Report:")
    idx_to_class = {i: c for i, c in enumerate(RealClassNames)}
    target_names = [idx_to_class[i] for i in range(NumClasses)]
    print(classification_report(TestLabelsList, TestPreds, target_names=target_names, zero_division=0))

    torch.save(Model.state_dict(), f"FixMatch_ESC50_{RunName}.pth")
    print(f"Model weights saved to FixMatch_ESC50_{RunName}.pth")

    return {
        "TrainLoss": TrainLossList,
        "TrainSupLoss": TrainSupLossList,
        "TrainUnsupLoss": TrainUnsupLossList,
        "TrainAcc": TrainAccList,
        "ValLoss": ValLossList,
        "ValAcc": ValAccList,
        "TestAcc": TestAcc,
        "RocAuc": RocAuc,
        "AvgPrecision": AvgPrecision
    }

def Main():
    DataDir = r"X:\Projects\ML\Project\esc_50"
    MetaDf = LoadMetaFromDirectory(DataDir)

    print("\nDataset Overview:")
    print(MetaDf.head())
    print(f"\nTotal number of recordings: {len(MetaDf)}")
    print(f"Unique major categories: {MetaDf['major_category'].nunique()}")
    print(f"Unique classes: {MetaDf['class_name'].nunique()}")

    print("\nPlotting Class Distribution:")
    PlotClassDistribution(MetaDf)

    print("\nPlotting Major Category Distribution:")
    PlotMajorCategoryDistribution(MetaDf)

    print("\nDisplaying Audio Waveforms & Spectrograms Of Random Samples:")
    DisplayRandomAudios(MetaDf, NumSamples=3)

    TrainDf, ValDf, TestDf = SplitTrainValTest(MetaDf, ValRatio=0.1, TestRatio=0.1)

    AllClasses = sorted(MetaDf["class_name"].unique())
    print(f"\nDetected {len(AllClasses)} total unique classes:", AllClasses)
    
    ResultsDict = {}
    LabeledCounts = [5, 9, 17, 26]

    for X in LabeledCounts:
        print(f"\n=== FixMatch with {X} labeled samples per class ===")
        LabeledDf, UnlabeledDf = FixedCountSplit(TrainDf, XPerClass=X)

        LabeledDataset = AudioReFixMatchDataset(LabeledDf, IsUnlabeled=False)
        UnlabeledDataset = AudioReFixMatchDataset(UnlabeledDf, IsUnlabeled=True)
        ValDataset = AudioTestDataset(ValDf)
        TestDatasetVar = AudioTestDataset(TestDf)

        BatchSize = 16
        LabeledLoader = DataLoader(LabeledDataset, batch_size=BatchSize, shuffle=True, num_workers=0)
        UnlabeledLoader = DataLoader(UnlabeledDataset, batch_size=BatchSize, shuffle=True, num_workers=0)
        ValLoader = DataLoader(ValDataset, batch_size=BatchSize, shuffle=False, num_workers=0)
        TestLoader = DataLoader(TestDatasetVar, batch_size=BatchSize, shuffle=False, num_workers=0)

        ModelVar = AudioDenseNet(NumClasses=len(AllClasses))

        RunName = f"{X}_PerClass"
        RunResults = TrainFixMatchAudio(
            Model=ModelVar,
            LabeledLoader=LabeledLoader,
            UnlabeledLoader=UnlabeledLoader,
            ValLoader=ValLoader,
            TestLoader=TestLoader,
            RealClassNames=AllClasses,
            NumEpochs=20,
            Lr=0.01,
            Tau=0.95,
            LambdaU=0.8,
            RunName=RunName
        )

        Epochs = range(1, len(RunResults["TrainLoss"])+1)

        plt.figure(figsize=(8,5))
        plt.plot(Epochs, RunResults["TrainLoss"], label="Total Train Loss", marker="o")
        plt.plot(Epochs, RunResults["TrainSupLoss"], label="Supervised Loss", marker="o")
        plt.plot(Epochs, RunResults["TrainUnsupLoss"], label="Unsupervised Loss", marker="o")
        plt.title(f"Training Loss Curves (FC={X})")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8,5))
        plt.plot(Epochs, RunResults["TrainAcc"], label="Train Accuracy", marker="o")
        plt.title(f"Training Accuracy (FC={X})")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8,5))
        plt.plot(Epochs, RunResults["ValLoss"], label="Validation Loss", marker="o", color="red")
        plt.title(f"Validation Loss (FC={X})")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8,5))
        plt.plot(Epochs, [val*100 for val in RunResults["ValAcc"]], label="Val Accuracy (%)", marker="o", color="green")
        plt.title(f"Validation Accuracy (FC={X})")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy (%)")
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8,5))
        plt.plot(Epochs, RunResults["TrainLoss"], label="Train Loss", marker="o")
        plt.plot(Epochs, RunResults["ValLoss"], label="Val Loss", marker="o", color="red")
        plt.title(f"Train vs. Val Loss (FC={X})")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.legend()
        plt.tight_layout()
        plt.show()

        ResultsDict[X] = RunResults
        print(f"Test Accuracy with {X} labeled/class: {RunResults['TestAcc']*100:.2f}%\n")

    print("\n========== SUMMARY OF ALL RUNS ==========")
    for X in LabeledCounts:
        Res = ResultsDict[X]
        print(f" Labeled/Class = {X}: TestAcc = {Res['TestAcc']*100:.2f}%, LastValAcc = {Res['ValAcc'][-1]*100:.2f}%")

if __name__ == "__main__":
    Main()
# Out:
# Dataset Overview:
#           filename major_category class_name  \
# 0  1-34094-A-5.wav        animals        cat
# 1  1-34094-B-5.wav        animals        cat
# 2  1-47819-A-5.wav        animals        cat
# 3  1-47819-B-5.wav        animals        cat
# 4  1-47819-C-5.wav        animals        cat
#
#                                            file_path
# 0  X:\Projects\ML\Project\esc_50\animals\cat\1-34...
# 1  X:\Projects\ML\Project\esc_50\animals\cat\1-34...
# 2  X:\Projects\ML\Project\esc_50\animals\cat\1-47...
# 3  X:\Projects\ML\Project\esc_50\animals\cat\1-47...
# 4  X:\Projects\ML\Project\esc_50\animals\cat\1-47...
#
# Total number of recordings: 2000
# Unique major categories: 5
# Unique classes: 50
#
# Plotting Class Distribution:
# Plotting Major Category Distribution:
# Displaying Audio Waveforms & Spectrograms Of Random Samples:
# Detected 50 total unique classes: ['airplane', 'breathing', 'brushing_teeth', 'can_opening', 'car_horn', 'cat', 'chainsaw', 'chirping_birds', 'church_bells', 'clapping', 'clock_alarm', 'clock_tick', 'coughing', 'cow', 'crackling_fire', 'crickets', 'crow', 'crying_baby', 'dog', 'door_wood_creaks', 'door_wood_knock', 'drinking_sipping', 'engine', 'fireworks', 'footsteps', 'frog', 'glass_breaking', 'hand_saw', 'helicopter', 'hen', 'insects', 'keyboard_typing', 'laughing', 'mouse_click', 'pig', 'pouring_water', 'rain', 'rooster', 'sea_waves', 'sheep', 'siren', 'sneezing', 'snoring', 'thunderstorm', 'toilet_flush', 'train', 'vacuum_cleaner', 'washing_machine', 'water_drops', 'wind']
#
# === FixMatch with 5 labeled samples per class ===
# 5_PerClass [Epoch 1/20] TrainLoss: 4.0656 (Sup=4.0656, Unsup=0.0000), TrainAcc: 0.00% | ValLoss: 3.9779, ValAcc: 3.00%
# 5_PerClass [Epoch 2/20] TrainLoss: 3.8496 (Sup=3.8496, Unsup=0.0000), TrainAcc: 6.40% | ValLoss: 3.6638, ValAcc: 10.50%
# 5_PerClass [Epoch 3/20] TrainLoss: 3.3399 (Sup=3.3399, Unsup=0.0000), TrainAcc: 17.60% | ValLoss: 3.2699, ValAcc: 14.50%
# 5_PerClass [Epoch 4/20] TrainLoss: 2.7195 (Sup=2.7195, Unsup=0.0000), TrainAcc: 31.60% | ValLoss: 2.7369, ValAcc: 32.00%
# 5_PerClass [Epoch 5/20] TrainLoss: 2.2162 (Sup=2.2142, Unsup=0.0026), TrainAcc: 40.40% | ValLoss: 2.3605, ValAcc: 31.00%
# 5_PerClass [Epoch 6/20] TrainLoss: 1.6507 (Sup=1.6507, Unsup=0.0000), TrainAcc: 59.60% | ValLoss: 2.1528, ValAcc: 44.00%
# 5_PerClass [Epoch 7/20] TrainLoss: 1.3147 (Sup=1.2964, Unsup=0.0229), TrainAcc: 66.40% | ValLoss: 2.1129, ValAcc: 46.00%
# 5_PerClass [Epoch 8/20] TrainLoss: 0.9218 (Sup=0.9140, Unsup=0.0097), TrainAcc: 77.60% | ValLoss: 1.8627, ValAcc: 53.50%
# 5_PerClass [Epoch 9/20] TrainLoss: 0.7397 (Sup=0.6876, Unsup=0.0652), TrainAcc: 83.60% | ValLoss: 2.1402, ValAcc: 48.00%
# 5_PerClass [Epoch 10/20] TrainLoss: 0.6864 (Sup=0.6461, Unsup=0.0504), TrainAcc: 83.60% | ValLoss: 1.9325, ValAcc: 52.50%
# 5_PerClass [Epoch 11/20] TrainLoss: 0.5310 (Sup=0.4916, Unsup=0.0493), TrainAcc: 86.40% | ValLoss: 1.8072, ValAcc: 58.00%
# 5_PerClass [Epoch 12/20] TrainLoss: 0.3729 (Sup=0.3344, Unsup=0.0481), TrainAcc: 94.80% | ValLoss: 1.8142, ValAcc: 53.50%
# 5_PerClass [Epoch 13/20] TrainLoss: 0.3805 (Sup=0.3483, Unsup=0.0402), TrainAcc: 95.20% | ValLoss: 1.7930, ValAcc: 58.50%
# 5_PerClass [Epoch 14/20] TrainLoss: 0.2853 (Sup=0.2356, Unsup=0.0622), TrainAcc: 96.80% | ValLoss: 1.9377, ValAcc: 59.00%
# 5_PerClass [Epoch 15/20] TrainLoss: 0.2524 (Sup=0.2012, Unsup=0.0640), TrainAcc: 98.00% | ValLoss: 1.8011, ValAcc: 60.00%
# 5_PerClass [Epoch 16/20] TrainLoss: 0.2411 (Sup=0.1719, Unsup=0.0865), TrainAcc: 97.60% | ValLoss: 1.6678, ValAcc: 60.50%
# 5_PerClass [Epoch 17/20] TrainLoss: 0.1528 (Sup=0.1103, Unsup=0.0531), TrainAcc: 100.00% | ValLoss: 1.6761, ValAcc: 61.00%
# 5_PerClass [Epoch 18/20] TrainLoss: 0.2007 (Sup=0.1174, Unsup=0.1041), TrainAcc: 100.00% | ValLoss: 1.6475, ValAcc: 64.00%
# 5_PerClass [Epoch 19/20] TrainLoss: 0.1731 (Sup=0.1311, Unsup=0.0525), TrainAcc: 99.60% | ValLoss: 1.6065, ValAcc: 64.50%
# 5_PerClass [Epoch 20/20] TrainLoss: 0.1426 (Sup=0.1006, Unsup=0.0524), TrainAcc: 99.20% | ValLoss: 1.6794, ValAcc: 62.00%
#
# 5_PerClass --- Final Test Results ---
# Test Accuracy: 58.00%
# ROC AUC: 0.9612, Average Precision (AUC-PRC): 0.6744
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#         airplane       0.50      0.25      0.33         4
#        breathing       0.50      0.25      0.33         4
#   brushing_teeth       0.75      0.75      0.75         4
#      can_opening       0.67      1.00      0.80         4
#         car_horn       0.60      0.75      0.67         4
#              cat       0.75      0.75      0.75         4
#         chainsaw       0.00      0.00      0.00         4
#   chirping_birds       1.00      1.00      1.00         4
#     church_bells       1.00      1.00      1.00         4
#         clapping       1.00      0.25      0.40         4
#      clock_alarm       1.00      0.75      0.86         4
#       clock_tick       0.38      0.75      0.50         4
#         coughing       0.75      0.75      0.75         4
#              cow       0.75      0.75      0.75         4
#   crackling_fire       0.57      1.00      0.73         4
#         crickets       1.00      0.50      0.67         4
#             crow       0.75      0.75      0.75         4
#      crying_baby       0.00      0.00      0.00         4
#              dog       0.67      0.50      0.57         4
# door_wood_creaks       0.50      0.50      0.50         4
#  door_wood_knock       0.80      1.00      0.89         4
# drinking_sipping       0.50      0.25      0.33         4
#           engine       0.67      0.50      0.57         4
#        fireworks       0.40      0.50      0.44         4
#        footsteps       0.40      0.50      0.44         4
#             frog       1.00      0.50      0.67         4
#   glass_breaking       1.00      0.75      0.86         4
#         hand_saw       0.67      1.00      0.80         4
#       helicopter       0.20      0.25      0.22         4
#              hen       0.67      1.00      0.80         4
#          insects       0.00      0.00      0.00         4
#  keyboard_typing       0.00      0.00      0.00         4
#         laughing       0.50      0.25      0.33         4
#      mouse_click       0.33      0.25      0.29         4
#              pig       0.00      0.00      0.00         4
#    pouring_water       1.00      0.75      0.86         4
#             rain       0.67      0.50      0.57         4
#          rooster       1.00      1.00      1.00         4
#        sea_waves       0.30      0.75      0.43         4
#            sheep       0.43      0.75      0.55         4
#            siren       0.80      1.00      0.89         4
#         sneezing       0.67      1.00      0.80         4
#          snoring       0.75      0.75      0.75         4
#     thunderstorm       1.00      0.75      0.86         4
#     toilet_flush       0.75      0.75      0.75         4
#            train       0.14      0.25      0.18         4
#   vacuum_cleaner       0.40      0.50      0.44         4
#  washing_machine       0.40      0.50      0.44         4
#      water_drops       1.00      0.25      0.40         4
#             wind       0.25      0.50      0.33         4
#
#         accuracy                           0.58       200
#        macro avg       0.60      0.58      0.56       200
#     weighted avg       0.60      0.58      0.56       200
#
# Model weights saved to FixMatch_ESC50_5_PerClass.pth
# Test Accuracy with 5 labeled/class: 58.00%
#
#
# === FixMatch with 9 labeled samples per class ===
# 9_PerClass [Epoch 1/20] TrainLoss: 3.9811 (Sup=3.9811, Unsup=0.0000), TrainAcc: 2.22% | ValLoss: 3.8371, ValAcc: 4.00%
# 9_PerClass [Epoch 2/20] TrainLoss: 3.5894 (Sup=3.5894, Unsup=0.0000), TrainAcc: 10.89% | ValLoss: 3.1279, ValAcc: 18.50%
# 9_PerClass [Epoch 3/20] TrainLoss: 2.8274 (Sup=2.8274, Unsup=0.0000), TrainAcc: 24.00% | ValLoss: 2.5858, ValAcc: 27.00%
# 9_PerClass [Epoch 4/20] TrainLoss: 2.2310 (Sup=2.2274, Unsup=0.0045), TrainAcc: 38.67% | ValLoss: 2.2430, ValAcc: 37.00%
# 9_PerClass [Epoch 5/20] TrainLoss: 1.8319 (Sup=1.8264, Unsup=0.0069), TrainAcc: 49.56% | ValLoss: 1.9644, ValAcc: 46.50%
# 9_PerClass [Epoch 6/20] TrainLoss: 1.5088 (Sup=1.4712, Unsup=0.0470), TrainAcc: 58.89% | ValLoss: 1.5445, ValAcc: 54.00%
# 9_PerClass [Epoch 7/20] TrainLoss: 1.1316 (Sup=1.1084, Unsup=0.0289), TrainAcc: 68.22% | ValLoss: 1.4948, ValAcc: 56.50%
# 9_PerClass [Epoch 8/20] TrainLoss: 0.9789 (Sup=0.9043, Unsup=0.0932), TrainAcc: 74.22% | ValLoss: 1.3788, ValAcc: 63.00%
# 9_PerClass [Epoch 9/20] TrainLoss: 0.8552 (Sup=0.8030, Unsup=0.0651), TrainAcc: 79.33% | ValLoss: 1.3178, ValAcc: 60.50%
# 9_PerClass [Epoch 10/20] TrainLoss: 0.6677 (Sup=0.6007, Unsup=0.0837), TrainAcc: 86.44% | ValLoss: 1.1321, ValAcc: 68.50%
# 9_PerClass [Epoch 11/20] TrainLoss: 0.5815 (Sup=0.4909, Unsup=0.1133), TrainAcc: 88.44% | ValLoss: 1.0950, ValAcc: 73.00%
# 9_PerClass [Epoch 12/20] TrainLoss: 0.5224 (Sup=0.4438, Unsup=0.0983), TrainAcc: 90.44% | ValLoss: 0.9844, ValAcc: 74.50%
# 9_PerClass [Epoch 13/20] TrainLoss: 0.4100 (Sup=0.3496, Unsup=0.0756), TrainAcc: 93.56% | ValLoss: 1.0403, ValAcc: 72.00%
# 9_PerClass [Epoch 14/20] TrainLoss: 0.3029 (Sup=0.2549, Unsup=0.0600), TrainAcc: 94.67% | ValLoss: 0.9611, ValAcc: 76.50%
# 9_PerClass [Epoch 15/20] TrainLoss: 0.3656 (Sup=0.2720, Unsup=0.1171), TrainAcc: 95.33% | ValLoss: 0.9235, ValAcc: 77.50%
# 9_PerClass [Epoch 16/20] TrainLoss: 0.3223 (Sup=0.2422, Unsup=0.1002), TrainAcc: 96.44% | ValLoss: 0.8169, ValAcc: 78.00%
# 9_PerClass [Epoch 17/20] TrainLoss: 0.2552 (Sup=0.1849, Unsup=0.0879), TrainAcc: 98.00% | ValLoss: 0.9727, ValAcc: 73.50%
# 9_PerClass [Epoch 18/20] TrainLoss: 0.2902 (Sup=0.2287, Unsup=0.0769), TrainAcc: 98.22% | ValLoss: 0.8495, ValAcc: 76.00%
# 9_PerClass [Epoch 19/20] TrainLoss: 0.2067 (Sup=0.1494, Unsup=0.0717), TrainAcc: 98.22% | ValLoss: 0.8343, ValAcc: 77.00%
# 9_PerClass [Epoch 20/20] TrainLoss: 0.2446 (Sup=0.1575, Unsup=0.1089), TrainAcc: 98.44% | ValLoss: 0.8530, ValAcc: 76.50%
#
# 9_PerClass --- Final Test Results ---
# Test Accuracy: 70.50%
# ROC AUC: 0.9865, Average Precision (AUC-PRC): 0.8212
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#         airplane       0.40      0.50      0.44         4
#        breathing       1.00      0.75      0.86         4
#   brushing_teeth       1.00      1.00      1.00         4
#      can_opening       0.60      0.75      0.67         4
#         car_horn       1.00      1.00      1.00         4
#              cat       0.80      1.00      0.89         4
#         chainsaw       0.67      0.50      0.57         4
#   chirping_birds       1.00      1.00      1.00         4
#     church_bells       1.00      1.00      1.00         4
#         clapping       1.00      0.25      0.40         4
#      clock_alarm       0.80      1.00      0.89         4
#       clock_tick       1.00      1.00      1.00         4
#         coughing       0.67      1.00      0.80         4
#              cow       0.75      0.75      0.75         4
#   crackling_fire       0.44      1.00      0.62         4
#         crickets       1.00      0.75      0.86         4
#             crow       1.00      0.75      0.86         4
#      crying_baby       1.00      0.75      0.86         4
#              dog       0.60      0.75      0.67         4
# door_wood_creaks       0.75      0.75      0.75         4
#  door_wood_knock       0.80      1.00      0.89         4
# drinking_sipping       0.67      0.50      0.57         4
#           engine       0.29      0.50      0.36         4
#        fireworks       0.43      0.75      0.55         4
#        footsteps       1.00      0.50      0.67         4
#             frog       0.75      0.75      0.75         4
#   glass_breaking       0.80      1.00      0.89         4
#         hand_saw       0.80      1.00      0.89         4
#       helicopter       0.50      0.25      0.33         4
#              hen       0.50      0.75      0.60         4
#          insects       0.67      0.50      0.57         4
#  keyboard_typing       0.75      0.75      0.75         4
#         laughing       1.00      0.25      0.40         4
#      mouse_click       0.50      0.25      0.33         4
#              pig       1.00      0.50      0.67         4
#    pouring_water       0.80      1.00      0.89         4
#             rain       0.33      0.25      0.29         4
#          rooster       1.00      1.00      1.00         4
#        sea_waves       0.50      0.50      0.50         4
#            sheep       0.60      0.75      0.67         4
#            siren       1.00      1.00      1.00         4
#         sneezing       0.80      1.00      0.89         4
#          snoring       0.75      0.75      0.75         4
#     thunderstorm       0.80      1.00      0.89         4
#     toilet_flush       1.00      0.75      0.86         4
#            train       0.50      0.25      0.33         4
#   vacuum_cleaner       0.33      0.25      0.29         4
#  washing_machine       0.33      0.50      0.40         4
#      water_drops       1.00      0.25      0.40         4
#             wind       0.50      0.50      0.50         4
#
#         accuracy                           0.70       200
#        macro avg       0.74      0.70      0.69       200
#     weighted avg       0.74      0.70      0.69       200
#
# Model weights saved to FixMatch_ESC50_9_PerClass.pth
# Test Accuracy with 9 labeled/class: 70.50%
#
#
# === FixMatch with 17 labeled samples per class ===
# 17_PerClass [Epoch 1/20] TrainLoss: 3.7967 (Sup=3.7967, Unsup=0.0000), TrainAcc: 7.65% | ValLoss: 3.4322, ValAcc: 15.00%
# 17_PerClass [Epoch 2/20] TrainLoss: 2.7077 (Sup=2.7076, Unsup=0.0002), TrainAcc: 24.12% | ValLoss: 2.5201, ValAcc: 35.00%
# 17_PerClass [Epoch 3/20] TrainLoss: 1.9513 (Sup=1.9379, Unsup=0.0167), TrainAcc: 46.00% | ValLoss: 1.7720, ValAcc: 52.50%
# 17_PerClass [Epoch 4/20] TrainLoss: 1.5286 (Sup=1.4873, Unsup=0.0516), TrainAcc: 56.47% | ValLoss: 1.6394, ValAcc: 54.50%
# 17_PerClass [Epoch 5/20] TrainLoss: 1.1474 (Sup=1.0839, Unsup=0.0795), TrainAcc: 66.71% | ValLoss: 1.4023, ValAcc: 57.00%
# 17_PerClass [Epoch 6/20] TrainLoss: 0.9745 (Sup=0.9205, Unsup=0.0675), TrainAcc: 71.53% | ValLoss: 1.1699, ValAcc: 65.00%
# 17_PerClass [Epoch 7/20] TrainLoss: 0.8363 (Sup=0.7504, Unsup=0.1074), TrainAcc: 78.12% | ValLoss: 0.9942, ValAcc: 75.00%
# 17_PerClass [Epoch 8/20] TrainLoss: 0.7602 (Sup=0.6665, Unsup=0.1171), TrainAcc: 80.59% | ValLoss: 1.0393, ValAcc: 72.00%
# 17_PerClass [Epoch 9/20] TrainLoss: 0.5891 (Sup=0.4903, Unsup=0.1235), TrainAcc: 87.18% | ValLoss: 0.8680, ValAcc: 71.50%
# 17_PerClass [Epoch 10/20] TrainLoss: 0.4927 (Sup=0.3916, Unsup=0.1263), TrainAcc: 89.41% | ValLoss: 0.8837, ValAcc: 73.50%
# 17_PerClass [Epoch 11/20] TrainLoss: 0.4237 (Sup=0.3209, Unsup=0.1286), TrainAcc: 91.65% | ValLoss: 0.7597, ValAcc: 79.50%
# 17_PerClass [Epoch 12/20] TrainLoss: 0.3533 (Sup=0.2345, Unsup=0.1485), TrainAcc: 94.71% | ValLoss: 0.7480, ValAcc: 80.00%
# 17_PerClass [Epoch 13/20] TrainLoss: 0.3018 (Sup=0.2208, Unsup=0.1013), TrainAcc: 95.41% | ValLoss: 0.8251, ValAcc: 76.50%
# 17_PerClass [Epoch 14/20] TrainLoss: 0.2449 (Sup=0.1423, Unsup=0.1283), TrainAcc: 96.47% | ValLoss: 0.6022, ValAcc: 84.00%
# 17_PerClass [Epoch 15/20] TrainLoss: 0.2098 (Sup=0.1214, Unsup=0.1105), TrainAcc: 97.53% | ValLoss: 0.7052, ValAcc: 77.00%
# 17_PerClass [Epoch 16/20] TrainLoss: 0.1549 (Sup=0.0949, Unsup=0.0750), TrainAcc: 98.24% | ValLoss: 0.7107, ValAcc: 82.00%
# 17_PerClass [Epoch 17/20] TrainLoss: 0.1828 (Sup=0.1099, Unsup=0.0912), TrainAcc: 98.71% | ValLoss: 0.6370, ValAcc: 82.00%
# 17_PerClass [Epoch 18/20] TrainLoss: 0.1465 (Sup=0.0775, Unsup=0.0862), TrainAcc: 99.53% | ValLoss: 0.6187, ValAcc: 84.50%
# 17_PerClass [Epoch 19/20] TrainLoss: 0.1384 (Sup=0.0672, Unsup=0.0890), TrainAcc: 98.59% | ValLoss: 0.6280, ValAcc: 82.00%
# 17_PerClass [Epoch 20/20] TrainLoss: 0.1467 (Sup=0.0583, Unsup=0.1106), TrainAcc: 99.18% | ValLoss: 0.5511, ValAcc: 87.00%
#
# 17_PerClass --- Final Test Results ---
# Test Accuracy: 80.00%
# ROC AUC: 0.9940, Average Precision (AUC-PRC): 0.8927
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#         airplane       0.33      0.25      0.29         4
#        breathing       0.75      0.75      0.75         4
#   brushing_teeth       0.50      1.00      0.67         4
#      can_opening       1.00      0.75      0.86         4
#         car_horn       1.00      1.00      1.00         4
#              cat       1.00      1.00      1.00         4
#         chainsaw       1.00      0.75      0.86         4
#   chirping_birds       1.00      1.00      1.00         4
#     church_bells       0.80      1.00      0.89         4
#         clapping       1.00      0.50      0.67         4
#      clock_alarm       1.00      1.00      1.00         4
#       clock_tick       1.00      1.00      1.00         4
#         coughing       1.00      1.00      1.00         4
#              cow       0.67      0.50      0.57         4
#   crackling_fire       0.57      1.00      0.73         4
#         crickets       1.00      0.25      0.40         4
#             crow       1.00      0.75      0.86         4
#      crying_baby       1.00      0.75      0.86         4
#              dog       1.00      0.75      0.86         4
# door_wood_creaks       0.75      0.75      0.75         4
#  door_wood_knock       0.80      1.00      0.89         4
# drinking_sipping       0.50      0.50      0.50         4
#           engine       0.50      0.50      0.50         4
#        fireworks       0.80      1.00      0.89         4
#        footsteps       1.00      1.00      1.00         4
#             frog       1.00      0.75      0.86         4
#   glass_breaking       0.80      1.00      0.89         4
#         hand_saw       1.00      1.00      1.00         4
#       helicopter       1.00      0.75      0.86         4
#              hen       0.80      1.00      0.89         4
#          insects       1.00      1.00      1.00         4
#  keyboard_typing       0.80      1.00      0.89         4
#         laughing       0.67      0.50      0.57         4
#      mouse_click       0.50      0.25      0.33         4
#              pig       1.00      0.50      0.67         4
#    pouring_water       1.00      1.00      1.00         4
#             rain       1.00      0.75      0.86         4
#          rooster       1.00      1.00      1.00         4
#        sea_waves       0.60      0.75      0.67         4
#            sheep       0.60      0.75      0.67         4
#            siren       1.00      1.00      1.00         4
#         sneezing       1.00      1.00      1.00         4
#          snoring       0.67      1.00      0.80         4
#     thunderstorm       1.00      0.75      0.86         4
#     toilet_flush       1.00      1.00      1.00         4
#            train       0.67      0.50      0.57         4
#   vacuum_cleaner       0.60      0.75      0.67         4
#  washing_machine       0.60      0.75      0.67         4
#      water_drops       1.00      0.75      0.86         4
#             wind       0.38      0.75      0.50         4
#
#         accuracy                           0.80       200
#        macro avg       0.83      0.80      0.80       200
#     weighted avg       0.83      0.80      0.80       200
#
# Model weights saved to FixMatch_ESC50_17_PerClass.pth
# Test Accuracy with 17 labeled/class: 80.00%
#
#
# === FixMatch with 26 labeled samples per class ===
# 26_PerClass [Epoch 1/20] TrainLoss: 3.6165 (Sup=3.6165, Unsup=0.0000), TrainAcc: 10.54% | ValLoss: 2.6729, ValAcc: 26.50%
# 26_PerClass [Epoch 2/20] TrainLoss: 2.3713 (Sup=2.3602, Unsup=0.0138), TrainAcc: 33.46% | ValLoss: 2.1326, ValAcc: 43.50%
# 26_PerClass [Epoch 3/20] TrainLoss: 1.7060 (Sup=1.6672, Unsup=0.0485), TrainAcc: 50.31% | ValLoss: 1.4342, ValAcc: 56.50%
# 26_PerClass [Epoch 4/20] TrainLoss: 1.4062 (Sup=1.3484, Unsup=0.0723), TrainAcc: 58.46% | ValLoss: 1.2951, ValAcc: 61.50%
# 26_PerClass [Epoch 5/20] TrainLoss: 1.1662 (Sup=1.1074, Unsup=0.0735), TrainAcc: 67.15% | ValLoss: 1.0518, ValAcc: 68.00%
# 26_PerClass [Epoch 6/20] TrainLoss: 0.8983 (Sup=0.8077, Unsup=0.1132), TrainAcc: 75.08% | ValLoss: 1.0650, ValAcc: 71.00%
# 26_PerClass [Epoch 7/20] TrainLoss: 0.7724 (Sup=0.6703, Unsup=0.1277), TrainAcc: 79.00% | ValLoss: 0.8259, ValAcc: 75.50%
# 26_PerClass [Epoch 8/20] TrainLoss: 0.6557 (Sup=0.5514, Unsup=0.1303), TrainAcc: 84.00% | ValLoss: 0.8833, ValAcc: 77.50%
# 26_PerClass [Epoch 9/20] TrainLoss: 0.4926 (Sup=0.3921, Unsup=0.1255), TrainAcc: 88.31% | ValLoss: 0.6256, ValAcc: 79.50%
# 26_PerClass [Epoch 10/20] TrainLoss: 0.4403 (Sup=0.3603, Unsup=0.1000), TrainAcc: 89.62% | ValLoss: 0.6997, ValAcc: 80.00%
# 26_PerClass [Epoch 11/20] TrainLoss: 0.3154 (Sup=0.2248, Unsup=0.1132), TrainAcc: 92.62% | ValLoss: 0.7306, ValAcc: 81.50%
# 26_PerClass [Epoch 12/20] TrainLoss: 0.2995 (Sup=0.2022, Unsup=0.1217), TrainAcc: 93.92% | ValLoss: 0.5345, ValAcc: 84.00%
# 26_PerClass [Epoch 13/20] TrainLoss: 0.2328 (Sup=0.1517, Unsup=0.1013), TrainAcc: 96.08% | ValLoss: 0.5478, ValAcc: 84.00%
# 26_PerClass [Epoch 14/20] TrainLoss: 0.1672 (Sup=0.0959, Unsup=0.0892), TrainAcc: 98.00% | ValLoss: 0.5771, ValAcc: 84.00%
# 26_PerClass [Epoch 15/20] TrainLoss: 0.1365 (Sup=0.0666, Unsup=0.0873), TrainAcc: 98.62% | ValLoss: 0.4750, ValAcc: 87.50%
# 26_PerClass [Epoch 16/20] TrainLoss: 0.1230 (Sup=0.0579, Unsup=0.0814), TrainAcc: 98.77% | ValLoss: 0.3930, ValAcc: 89.00%
# 26_PerClass [Epoch 17/20] TrainLoss: 0.1104 (Sup=0.0472, Unsup=0.0790), TrainAcc: 99.31% | ValLoss: 0.4900, ValAcc: 87.00%
# 26_PerClass [Epoch 18/20] TrainLoss: 0.1004 (Sup=0.0472, Unsup=0.0665), TrainAcc: 99.08% | ValLoss: 0.4966, ValAcc: 85.50%
# 26_PerClass [Epoch 19/20] TrainLoss: 0.0845 (Sup=0.0292, Unsup=0.0692), TrainAcc: 99.69% | ValLoss: 0.4927, ValAcc: 86.50%
# 26_PerClass [Epoch 20/20] TrainLoss: 0.1101 (Sup=0.0556, Unsup=0.0682), TrainAcc: 98.92% | ValLoss: 0.4715, ValAcc: 86.00%
#
# 26_PerClass --- Final Test Results ---
# Test Accuracy: 87.50%
# ROC AUC: 0.9952, Average Precision (AUC-PRC): 0.9269
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#         airplane       0.50      1.00      0.67         4
#        breathing       1.00      0.75      0.86         4
#   brushing_teeth       0.80      1.00      0.89         4
#      can_opening       1.00      0.75      0.86         4
#         car_horn       1.00      1.00      1.00         4
#              cat       1.00      1.00      1.00         4
#         chainsaw       0.75      0.75      0.75         4
#   chirping_birds       1.00      1.00      1.00         4
#     church_bells       1.00      0.75      0.86         4
#         clapping       1.00      0.75      0.86         4
#      clock_alarm       1.00      1.00      1.00         4
#       clock_tick       1.00      1.00      1.00         4
#         coughing       0.80      1.00      0.89         4
#              cow       0.80      1.00      0.89         4
#   crackling_fire       0.67      1.00      0.80         4
#         crickets       1.00      0.50      0.67         4
#             crow       1.00      1.00      1.00         4
#      crying_baby       0.75      0.75      0.75         4
#              dog       1.00      1.00      1.00         4
# door_wood_creaks       0.80      1.00      0.89         4
#  door_wood_knock       1.00      1.00      1.00         4
# drinking_sipping       1.00      0.75      0.86         4
#           engine       1.00      0.75      0.86         4
#        fireworks       1.00      1.00      1.00         4
#        footsteps       1.00      1.00      1.00         4
#             frog       1.00      1.00      1.00         4
#   glass_breaking       0.80      1.00      0.89         4
#         hand_saw       1.00      1.00      1.00         4
#       helicopter       0.80      1.00      0.89         4
#              hen       0.80      1.00      0.89         4
#          insects       1.00      1.00      1.00         4
#  keyboard_typing       0.67      1.00      0.80         4
#         laughing       0.67      0.50      0.57         4
#      mouse_click       0.75      0.75      0.75         4
#              pig       1.00      0.75      0.86         4
#    pouring_water       1.00      0.75      0.86         4
#             rain       0.80      1.00      0.89         4
#          rooster       1.00      1.00      1.00         4
#        sea_waves       0.50      0.25      0.33         4
#            sheep       1.00      0.75      0.86         4
#            siren       1.00      1.00      1.00         4
#         sneezing       1.00      1.00      1.00         4
#          snoring       1.00      1.00      1.00         4
#     thunderstorm       0.80      1.00      0.89         4
#     toilet_flush       1.00      0.75      0.86         4
#            train       1.00      0.50      0.67         4
#   vacuum_cleaner       0.60      0.75      0.67         4
#  washing_machine       1.00      1.00      1.00         4
#      water_drops       1.00      0.50      0.67         4
#             wind       0.80      1.00      0.89         4
#
#         accuracy                           0.88       200
#        macro avg       0.90      0.88      0.87       200
#     weighted avg       0.90      0.88      0.87       200
#
# Model weights saved to FixMatch_ESC50_26_PerClass.pth
# Test Accuracy with 26 labeled/class: 87.50%
#
#
# ========== SUMMARY OF ALL RUNS ==========
#  Labeled/Class = 5: TestAcc = 58.00%, LastValAcc = 62.00%
#  Labeled/Class = 9: TestAcc = 70.50%, LastValAcc = 76.50%
#  Labeled/Class = 17: TestAcc = 80.00%, LastValAcc = 87.00%
#  Labeled/Class = 26: TestAcc = 87.50%, LastValAcc = 86.00%
