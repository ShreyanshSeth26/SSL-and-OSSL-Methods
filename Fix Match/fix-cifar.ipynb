# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from PIL import Image
import warnings
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.models as Models
from sklearn.model_selection import train_test_split
import albumentations as A
from albumentations.pytorch import ToTensorV2
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, average_precision_score
from tqdm import tqdm

RandomState = 2022484
np.random.seed(RandomState)
random.seed(RandomState)
torch.manual_seed(RandomState)
Device = torch.device("cuda")
warnings.filterwarnings("ignore", category=FutureWarning)

class DenseNetRefixMatch(nn.Module):
    def __init__(self, NumClasses=100):
        super(DenseNetRefixMatch, self).__init__()
        Backbone = Models.densenet121(weights=Models.DenseNet121_Weights.DEFAULT)
        Backbone.features.conv0 = nn.Conv2d(
            in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False
        )
        nn.init.kaiming_normal_(Backbone.features.conv0.weight, mode='fan_out', nonlinearity='relu')
        self.Features = Backbone.features
        self.Classifier = nn.Linear(Backbone.classifier.in_features, NumClasses)
        
    def forward(self, X):
        FeaturesOut = self.Features(X)
        ReluOut = F.relu(FeaturesOut, inplace=True)
        PooledOut = F.adaptive_avg_pool2d(ReluOut, (1, 1))
        FlattenedOut = torch.flatten(PooledOut, 1)
        Logits = self.Classifier(FlattenedOut)
        return Logits

def LoadCifar100(DatasetPath):
    Data = []
    ClassToIdx = {}
    IdxToClass = {}
    SuperclassToClass = {}
    IdxToSuperclass = {}

    for SuperclassIdx, (Superclass, ClassDirs) in enumerate(
            [(Folder, os.listdir(os.path.join(DatasetPath, Folder))) for Folder in os.listdir(DatasetPath)]
        ):
        SuperclassToClass[Superclass] = []
        IdxToSuperclass[SuperclassIdx] = Superclass
        for ClassName in ClassDirs:
            ClassPath = os.path.join(DatasetPath, Superclass, ClassName)
            if os.path.isdir(ClassPath):
                if ClassName not in ClassToIdx:
                    ClassToIdx[ClassName] = len(ClassToIdx)
                    IdxToClass[ClassToIdx[ClassName]] = ClassName
                SuperclassToClass[Superclass].append(ClassToIdx[ClassName])
                for ImgPath in glob(os.path.join(ClassPath, "*.png")):
                    ImageArray = np.array(Image.open(ImgPath).convert("RGB"))
                    Data.append((ImageArray, ClassToIdx[ClassName], SuperclassIdx))
    print(f"Dataset loaded with {len(Data)} images across {len(ClassToIdx)} classes and {len(SuperclassToClass)} superclasses.")
    return Data, ClassToIdx, IdxToClass, SuperclassToClass, IdxToSuperclass

def PlotClassDistribution(Data, IdxToClass):
    ClassCounts = {}
    for (_, Label, _) in Data:
        ClassName = IdxToClass[Label]
        ClassCounts[ClassName] = ClassCounts.get(ClassName, 0) + 1
    SortedClasses = sorted(ClassCounts.keys())
    Counts = [ClassCounts[Cls] for Cls in SortedClasses]
    plt.figure(figsize=(20, 6))
    sns.barplot(x=SortedClasses, y=Counts)
    plt.title("CIFAR-100 Class Distribution", fontsize=16)
    plt.xlabel("Class Name", fontsize=14)
    plt.ylabel("Image Count", fontsize=14)
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

def PlotSuperclassDistribution(Data, IdxToSuperclass):
    SuperclassCounts = {}
    for (_, _, Superclass) in Data:
        SuperclassName = IdxToSuperclass[Superclass]
        SuperclassCounts[SuperclassName] = SuperclassCounts.get(SuperclassName, 0) + 1
    SortedSuperclasses = sorted(SuperclassCounts.keys())
    Counts = [SuperclassCounts[Scls] for Scls in SortedSuperclasses]
    plt.figure(figsize=(12, 6))
    sns.barplot(x=SortedSuperclasses, y=Counts)
    plt.title("CIFAR-100 Superclass Distribution", fontsize=16)
    plt.xlabel("Superclass Name", fontsize=14)
    plt.ylabel("Image Count", fontsize=14)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

def DisplayRandomImages(Data, IdxToClass, IdxToSuperclass, NumImages=20):
    RandomIndices = random.sample(range(len(Data)), NumImages)
    SelectedData = [Data[i] for i in RandomIndices]
    fig, Axes = plt.subplots(4, 5, figsize=(12, 10))
    for Ax, (ImageArray, Label, Superclass) in zip(Axes.flat, SelectedData):
        Ax.imshow(ImageArray)
        Ax.axis("off")
        Ax.set_title(f"{IdxToClass[Label]}\n({IdxToSuperclass[Superclass]})", fontsize=8)
    plt.suptitle("Random Sample Images from CIFAR-100", fontsize=18)
    plt.tight_layout()
    plt.show()

def DisplayAugmentedImages(Data, NumImages=10):
    WeakTransform = A.Compose([
        A.RandomCrop(32, 32, p=1.0),
        A.HorizontalFlip(p=1.0)
    ])
    StrongTransform = A.Compose([
        A.Perspective(scale=(0.05, 0.1), p=1.0),
        A.Affine(shear=15, p=1.0),
        A.OneOf([
            A.GaussianBlur(blur_limit=(3, 7), p=1.0),
            A.RandomBrightnessContrast(p=1.0),
            A.RandomGamma(p=1.0)
        ], p=1.0)
    ])
    RandomSamples = random.sample(Data, NumImages)
    fig, Axes = plt.subplots(3, NumImages, figsize=(15, 10))
    for I, (ImageArray, _, _) in enumerate(RandomSamples):
        Original = ImageArray
        WeakAug = WeakTransform(image=Original)['image']
        StrongAug = StrongTransform(image=Original)['image']
        Axes[0, I].imshow(Original)
        Axes[0, I].axis("off")
        Axes[0, I].set_title("Original", fontsize=8)
        Axes[1, I].imshow(WeakAug)
        Axes[1, I].axis("off")
        Axes[1, I].set_title("Weak Augmentation", fontsize=8)
        Axes[2, I].imshow(StrongAug)
        Axes[2, I].axis("off")
        Axes[2, I].set_title("Strong Augmentation", fontsize=8)
    plt.suptitle("Demonstration of Image Augmentations", fontsize=18)
    plt.tight_layout()
    plt.show()

def FixedCountSplit(Data, NumPerClass):
    ClassDict = {}
    for Item in Data:
        ImageArray, Label, Superclass = Item
        if Label not in ClassDict:
            ClassDict[Label] = []
        ClassDict[Label].append(Item)
    Labeled = []
    Unlabeled = []
    for Label, Items in ClassDict.items():
        random.shuffle(Items)
        if len(Items) > NumPerClass:
            Labeled.extend(Items[:NumPerClass])
            Unlabeled.extend(Items[NumPerClass:])
        else:
            Labeled.extend(Items)
    return Labeled, Unlabeled

def SplitDataFixedCountAlt(Data, NumPerClass):
    TrainData, TempData = train_test_split(
        Data, train_size=0.8, stratify=[X[1] for X in Data], random_state=RandomState
    )
    ValData, TestData = train_test_split(
        TempData, train_size=0.5, stratify=[X[1] for X in TempData], random_state=RandomState
    )
    LabeledData, UnlabeledData = FixedCountSplit(TrainData, NumPerClass)
    print(f"\n[Data Split] Fixed Count: {NumPerClass} labeled samples per class")
    print(f"Labeled Training Data: {len(LabeledData)} samples")
    print(f"Unlabeled Training Data: {len(UnlabeledData)} samples")
    print(f"Validation Data: {len(ValData)} samples")
    print(f"Test Data: {len(TestData)} samples")
    return LabeledData, UnlabeledData, ValData, TestData

class Cifar100ReFixMatchDataset(Dataset):
    def __init__(self, Data, TransformOriginal, TransformWeak, TransformStrong):
        self.Data = Data
        self.TransformOriginal = TransformOriginal
        self.TransformWeak = TransformWeak
        self.TransformStrong = TransformStrong

    def __getitem__(self, Index):
        ImageArray, Label, _ = self.Data[Index]
        Original = self.TransformOriginal(image=ImageArray)['image']
        Weak = self.TransformWeak(image=ImageArray)['image']
        Strong = self.TransformStrong(image=ImageArray)['image']
        return {'Original': Original, 'Weak': Weak, 'Strong': Strong, 'Label': Label}

    def __len__(self):
        return len(self.Data)

class Cifar100TestDataset(Dataset):
    def __init__(self, Data, Transform):
        self.Data = Data
        self.Transform = Transform

    def __getitem__(self, Index):
        ImageArray, Label, _ = self.Data[Index]
        Transformed = self.Transform(image=ImageArray)['image']
        return Transformed, Label

    def __len__(self):
        return len(self.Data)

def main():
    Mean = (0.5, 0.5, 0.5)
    Std = (0.5, 0.5, 0.5)
    TransformOriginal = A.Compose([
        A.Resize(32, 32),
        A.Normalize(mean=Mean, std=Std, max_pixel_value=255.0),
        ToTensorV2()
    ])
    TransformWeak = A.Compose([
        A.Resize(32, 32),
        A.RandomCrop(32, 32, p=1.0),
        A.HorizontalFlip(p=1.0),
        A.Normalize(mean=Mean, std=Std, max_pixel_value=255.0),
        ToTensorV2()
    ])
    TransformStrong = A.Compose([
        A.Resize(32, 32),
        A.Perspective(scale=(0.05, 0.1), p=1.0),
        A.Affine(shear=15, p=1.0),
        A.OneOf([
            A.GaussianBlur(blur_limit=(3, 7), p=1.0),
            A.RandomBrightnessContrast(p=1.0),
            A.RandomGamma(p=1.0)
        ], p=1.0),
        A.Normalize(mean=Mean, std=Std, max_pixel_value=255.0),
        ToTensorV2()
    ])

    dataset_path = r"X:\Projects\ML\Project\cifar_100"
    Data, ClassToIdx, IdxToClass, SuperclassToClass, IdxToSuperclass = LoadCifar100(dataset_path)

    PlotClassDistribution(Data, IdxToClass)
    PlotSuperclassDistribution(Data, IdxToSuperclass)
    DisplayRandomImages(Data, IdxToClass, IdxToSuperclass, NumImages=20)
    DisplayAugmentedImages(Data, NumImages=10)

    FixedCounts = [75, 175, 260, 360]
    Results = {}       
    AllMetrics = {} 
    Eps = 1e-8
    Tau = 0.95
    LambdaU = 0.8
    NumEpochs = 20

    for FixedCount in FixedCounts:
        print(f"\n=== Running experiment with {FixedCount} labeled samples per class ===")
        LabeledDataFixed, UnlabeledDataFixed, ValDataFixed, TestDataFixed = SplitDataFixedCountAlt(Data, FixedCount)

        LabeledDatasetFixed = Cifar100ReFixMatchDataset(
            Data=LabeledDataFixed, TransformOriginal=TransformOriginal,
            TransformWeak=TransformWeak, TransformStrong=TransformStrong
        )
        UnlabeledDatasetFixed = Cifar100ReFixMatchDataset(
            Data=UnlabeledDataFixed, TransformOriginal=TransformOriginal,
            TransformWeak=TransformWeak, TransformStrong=TransformStrong
        )
        BatchSize = 256
        LabeledLoaderFixed = DataLoader(LabeledDatasetFixed, batch_size=BatchSize, shuffle=True, num_workers=0)
        UnlabeledLoaderFixed = DataLoader(UnlabeledDatasetFixed, batch_size=BatchSize, shuffle=True, num_workers=0)

        ModelFixed = DenseNetRefixMatch(NumClasses=100).to(Device)
        OptimizerFixed = torch.optim.SGD(ModelFixed.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-3)
        Scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(OptimizerFixed, T_max=NumEpochs)

        TrainLossList = []
        TrainSupLossList = []
        TrainUnsupLossList = []
        TrainAccList = []
        ValLossList = []
        ValAccList = []

        for Epoch in range(NumEpochs):
            ModelFixed.train()
            TotalLoss = 0.0
            TotalSupLoss = 0.0
            TotalUnsupLoss = 0.0
            TotalTrainCorrect = 0
            TotalTrainSamples = 0
            NumBatches = 0
            UnlabeledIter = iter(UnlabeledLoaderFixed)

            for LabeledBatch in tqdm(LabeledLoaderFixed, desc=f"Epoch {Epoch+1}/{NumEpochs}", leave=False):
                try:
                    UnlabeledBatch = next(UnlabeledIter)
                except StopIteration:
                    UnlabeledIter = iter(UnlabeledLoaderFixed)
                    UnlabeledBatch = next(UnlabeledIter)

                InputsL = LabeledBatch["Weak"].to(Device)
                Labels = LabeledBatch["Label"].to(Device).long()

                LogitsL = ModelFixed(InputsL)
                LossSupervised = F.cross_entropy(LogitsL, Labels)

                PredsL = torch.argmax(LogitsL, dim=1)
                TotalTrainCorrect += (PredsL == Labels).sum().item()
                TotalTrainSamples += Labels.size(0)

                InputsUWeak = UnlabeledBatch["Weak"].float().to(Device)
                InputsUStrong = UnlabeledBatch["Strong"].float().to(Device)
                with torch.no_grad():
                    LogitsUWeak = ModelFixed(InputsUWeak)
                    ProbsUWeak = F.softmax(LogitsUWeak, dim=1)

                MaxProbs, PseudoLabels = torch.max(ProbsUWeak, dim=1)
                Mask = (MaxProbs >= Tau).float()

                LogitsUStrong = ModelFixed(InputsUStrong)
                LossUnlabeled = F.cross_entropy(LogitsUStrong, PseudoLabels, reduction="none")
                LossUnlabeled = (LossUnlabeled * Mask).mean()

                Loss = LossSupervised + LambdaU * LossUnlabeled

                OptimizerFixed.zero_grad()
                Loss.backward()
                torch.nn.utils.clip_grad_norm_(ModelFixed.parameters(), max_norm=5.0)
                OptimizerFixed.step()

                TotalLoss += Loss.item()
                TotalSupLoss += LossSupervised.item()
                TotalUnsupLoss += LossUnlabeled.item()
                NumBatches += 1

            AvgLoss = TotalLoss / NumBatches
            AvgSupLoss = TotalSupLoss / NumBatches
            AvgUnsupLoss = TotalUnsupLoss / NumBatches
            TrainAcc = TotalTrainCorrect / TotalTrainSamples

            TrainLossList.append(AvgLoss)
            TrainSupLossList.append(AvgSupLoss)
            TrainUnsupLossList.append(AvgUnsupLoss)
            TrainAccList.append(TrainAcc)

            ModelFixed.eval()
            ValLoss = 0.0
            ValBatches = 0
            ValPreds = []
            ValLabels = []
            ValDataset = Cifar100TestDataset(Data=ValDataFixed, Transform=TransformOriginal)
            ValLoader = DataLoader(ValDataset, batch_size=256, shuffle=False, num_workers=0)

            with torch.no_grad():
                for Images, Labels_Val in ValLoader:
                    Images = Images.float().to(Device)
                    Labels_Val = Labels_Val.to(Device).long()
                    LogitsVal = ModelFixed(Images)
                    LossVal = F.cross_entropy(LogitsVal, Labels_Val)
                    ValLoss += LossVal.item()
                    ValBatches += 1
                    Preds = torch.argmax(LogitsVal, dim=1)
                    ValPreds.extend(Preds.cpu().numpy())
                    ValLabels.extend(Labels_Val.cpu().numpy())

            AvgValLoss = ValLoss / ValBatches
            ValAccuracy = accuracy_score(ValLabels, ValPreds)
            ValLossList.append(AvgValLoss)
            ValAccList.append(ValAccuracy)

            print(f"[Epoch Completed] FC={FixedCount}  Ep[{Epoch+1}/{NumEpochs}]  "
                  f"TrainLoss: {AvgLoss:.4f} | TrainAcc: {TrainAcc*100:.2f}%  "
                  f"SupLoss: {AvgSupLoss:.4f} | UnsupLoss: {AvgUnsupLoss:.4f}  "
                  f"ValLoss: {AvgValLoss:.4f} | ValAcc: {ValAccuracy*100:.2f}%")
            Scheduler.step()

        torch.save(ModelFixed.state_dict(), f"FixMatch_CIFAR100_{FixedCount}_Per_Class.pth")

        TestDatasetFixed = Cifar100TestDataset(Data=TestDataFixed, Transform=TransformOriginal)
        TestLoaderFixed = DataLoader(TestDatasetFixed, batch_size=256, shuffle=False, num_workers=0)

        AllPreds = []
        AllLabels = []
        TestProbsList = []
        ModelFixed.eval()
        with torch.no_grad():
            for Images, Labels_ in TestLoaderFixed:
                Images = Images.float().to(Device)
                Labels_ = Labels_.to(Device).long()
                LogitsTest = ModelFixed(Images)
                ProbsTest = F.softmax(LogitsTest, dim=1)
                Preds = torch.argmax(LogitsTest, dim=1)
                AllPreds.extend(Preds.cpu().numpy())
                AllLabels.extend(Labels_.cpu().numpy())
                TestProbsList.extend(ProbsTest.cpu().numpy())

        TestAcc = accuracy_score(AllLabels, AllPreds)
        OneHotTestLabels = np.eye(100)[np.array(AllLabels)]
        RocAuc = roc_auc_score(OneHotTestLabels, np.array(TestProbsList), multi_class="ovr")
        AvgPrecision = average_precision_score(OneHotTestLabels, np.array(TestProbsList), average="macro")

        print(f"\n[Test Evaluation] FC={FixedCount}  "
              f"Test Accuracy: {TestAcc*100:.2f}% | ROC AUC: {RocAuc:.4f} | AvgPrecision: {AvgPrecision:.4f}")

        TargetNames = [IdxToClass[i] for i in range(len(IdxToClass))]
        print(classification_report(AllLabels, AllPreds, target_names=TargetNames, zero_division=0))

        Results[FixedCount] = TestAcc
        AllMetrics[FixedCount] = {
            "TrainLoss": TrainLossList,
            "TrainSupLoss": TrainSupLossList,
            "TrainUnsupLoss": TrainUnsupLossList,
            "TrainAcc": TrainAccList,
            "ValLoss": ValLossList,
            "ValAcc": ValAccList,
            "TestAcc": TestAcc
        }

        plt.figure(figsize=(8, 5))
        plt.plot(AllMetrics[FixedCount]["TrainLoss"], label="Total Train Loss", marker="o")
        plt.plot(AllMetrics[FixedCount]["TrainSupLoss"], label="Supervised", marker="o")
        plt.plot(AllMetrics[FixedCount]["TrainUnsupLoss"], label="Unsupervised", marker="o")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.title(f"Training Loss Curves (FC={FixedCount})")
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8, 5))
        plt.plot(AllMetrics[FixedCount]["TrainAcc"], label="Train Accuracy", marker="o")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy")
        plt.title(f"Training Accuracy (FC={FixedCount})")
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8, 5))
        plt.plot(AllMetrics[FixedCount]["ValLoss"], label="Validation Loss", marker="o", color="red")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.title(f"Validation Loss (FC={FixedCount})")
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8, 5))
        plt.plot([v * 100 for v in AllMetrics[FixedCount]["ValAcc"]], label="Val Accuracy (%)", marker="o", color="green")
        plt.xlabel("Epoch")
        plt.ylabel("Accuracy (%)")
        plt.title(f"Validation Accuracy (FC={FixedCount})")
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8, 5))
        plt.plot(AllMetrics[FixedCount]["TrainLoss"], label="Train Loss", marker="o")
        plt.plot(AllMetrics[FixedCount]["ValLoss"], label="Val Loss", marker="o", color="red")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.title(f"Train vs. Val Loss (FC={FixedCount})")
        plt.legend()
        plt.tight_layout()
        plt.show()

        print(f"--- Finished plotting for {FixedCount} labeled/class ---")

    BestFixedCount = max(Results, key=Results.get)
    print(f"\n[Test Summary] Best run: {BestFixedCount} labeled samples per class "
          f"with Test Accuracy: {Results[BestFixedCount]*100:.2f}%")

if __name__ == '__main__':
    from multiprocessing import freeze_support
    freeze_support()
    main()
# Out:
# Dataset loaded with 60000 images across 100 classes and 20 superclasses.
# === Running experiment with 75 labeled samples per class ===
#
# [Data Split] Fixed Count: 75 labeled samples per class
# Labeled Training Data: 7500 samples
# Unlabeled Training Data: 40500 samples
# Validation Data: 6000 samples
# Test Data: 6000 samples
# [Epoch Completed] FC=75  Ep[1/20]  TrainLoss: 4.6277 | TrainAcc: 2.68%  SupLoss: 4.6269 | UnsupLoss: 0.0010  ValLoss: 4.4345 | ValAcc: 5.28%
# [Epoch Completed] FC=75  Ep[2/20]  TrainLoss: 3.9210 | TrainAcc: 13.47%  SupLoss: 3.9168 | UnsupLoss: 0.0052  ValLoss: 3.6715 | ValAcc: 16.47%
# [Epoch Completed] FC=75  Ep[3/20]  TrainLoss: 2.9901 | TrainAcc: 29.69%  SupLoss: 2.9815 | UnsupLoss: 0.0108  ValLoss: 3.1766 | ValAcc: 23.52%
# [Epoch Completed] FC=75  Ep[4/20]  TrainLoss: 2.1124 | TrainAcc: 49.39%  SupLoss: 2.1007 | UnsupLoss: 0.0146  ValLoss: 2.9512 | ValAcc: 28.02%
# [Epoch Completed] FC=75  Ep[5/20]  TrainLoss: 1.4149 | TrainAcc: 69.15%  SupLoss: 1.3919 | UnsupLoss: 0.0287  ValLoss: 2.9216 | ValAcc: 28.80%
# [Epoch Completed] FC=75  Ep[6/20]  TrainLoss: 0.8606 | TrainAcc: 85.16%  SupLoss: 0.8270 | UnsupLoss: 0.0420  ValLoss: 2.9048 | ValAcc: 30.07%
# [Epoch Completed] FC=75  Ep[7/20]  TrainLoss: 0.4637 | TrainAcc: 95.35%  SupLoss: 0.4212 | UnsupLoss: 0.0531  ValLoss: 2.9243 | ValAcc: 30.65%
# [Epoch Completed] FC=75  Ep[8/20]  TrainLoss: 0.2599 | TrainAcc: 99.01%  SupLoss: 0.2047 | UnsupLoss: 0.0690  ValLoss: 2.9592 | ValAcc: 30.70%
# [Epoch Completed] FC=75  Ep[9/20]  TrainLoss: 0.1836 | TrainAcc: 99.76%  SupLoss: 0.1173 | UnsupLoss: 0.0828  ValLoss: 3.0132 | ValAcc: 31.40%
# [Epoch Completed] FC=75  Ep[10/20]  TrainLoss: 0.1593 | TrainAcc: 99.89%  SupLoss: 0.0851 | UnsupLoss: 0.0927  ValLoss: 3.0279 | ValAcc: 31.38%
# [Epoch Completed] FC=75  Ep[11/20]  TrainLoss: 0.1555 | TrainAcc: 99.99%  SupLoss: 0.0659 | UnsupLoss: 0.1120  ValLoss: 3.0312 | ValAcc: 31.55%
# [Epoch Completed] FC=75  Ep[12/20]  TrainLoss: 0.1332 | TrainAcc: 99.97%  SupLoss: 0.0575 | UnsupLoss: 0.0946  ValLoss: 3.0536 | ValAcc: 31.25%
# [Epoch Completed] FC=75  Ep[13/20]  TrainLoss: 0.1317 | TrainAcc: 99.99%  SupLoss: 0.0499 | UnsupLoss: 0.1023  ValLoss: 3.0707 | ValAcc: 31.70%
# [Epoch Completed] FC=75  Ep[14/20]  TrainLoss: 0.1349 | TrainAcc: 99.93%  SupLoss: 0.0446 | UnsupLoss: 0.1128  ValLoss: 3.0880 | ValAcc: 31.92%
# [Epoch Completed] FC=75  Ep[15/20]  TrainLoss: 0.1293 | TrainAcc: 99.97%  SupLoss: 0.0418 | UnsupLoss: 0.1093  ValLoss: 3.0790 | ValAcc: 31.93%
# [Epoch Completed] FC=75  Ep[16/20]  TrainLoss: 0.1149 | TrainAcc: 99.97%  SupLoss: 0.0373 | UnsupLoss: 0.0970  ValLoss: 3.0736 | ValAcc: 32.15%
# [Epoch Completed] FC=75  Ep[17/20]  TrainLoss: 0.1133 | TrainAcc: 100.00%  SupLoss: 0.0331 | UnsupLoss: 0.1002  ValLoss: 3.0889 | ValAcc: 31.82%
# [Epoch Completed] FC=75  Ep[18/20]  TrainLoss: 0.1159 | TrainAcc: 99.99%  SupLoss: 0.0322 | UnsupLoss: 0.1047  ValLoss: 3.0807 | ValAcc: 32.25%
# [Epoch Completed] FC=75  Ep[19/20]  TrainLoss: 0.1107 | TrainAcc: 99.97%  SupLoss: 0.0331 | UnsupLoss: 0.0970  ValLoss: 3.0981 | ValAcc: 32.03%
# [Epoch Completed] FC=75  Ep[20/20]  TrainLoss: 0.1121 | TrainAcc: 99.99%  SupLoss: 0.0311 | UnsupLoss: 0.1013  ValLoss: 3.0886 | ValAcc: 32.10%
#
# [Test Evaluation] FC=75  Test Accuracy: 32.62% | ROC AUC: 0.9151 | AvgPrecision: 0.3109
#                precision    recall  f1-score   support
#
#        beaver       0.05      0.05      0.05        60
#       dolphin       0.31      0.43      0.36        60
#         otter       0.09      0.07      0.07        60
#          seal       0.10      0.03      0.05        60
#         whale       0.33      0.40      0.36        60
# aquarium fish       0.36      0.25      0.29        60
#      flatfish       0.28      0.12      0.16        60
#           ray       0.35      0.25      0.29        60
#         shark       0.51      0.42      0.46        60
#         trout       0.44      0.53      0.48        60
#        orchid       0.41      0.40      0.41        60
#         poppy       0.37      0.55      0.44        60
#          rose       0.42      0.35      0.38        60
#     sunflower       0.67      0.70      0.68        60
#         tulip       0.22      0.15      0.18        60
#        bottle       0.44      0.60      0.51        60
#          bowl       0.38      0.22      0.28        60
#           can       0.37      0.35      0.36        60
#           cup       0.38      0.55      0.45        60
#         plate       0.53      0.42      0.47        60
#         apple       0.60      0.63      0.62        60
#      mushroom       0.32      0.37      0.34        60
#        orange       0.55      0.70      0.61        60
#          pear       0.40      0.35      0.37        60
#  sweet pepper       0.28      0.22      0.24        60
#         clock       0.44      0.33      0.38        60
#      keyboard       0.46      0.73      0.57        60
#          lamp       0.39      0.18      0.25        60
#     telephone       0.26      0.15      0.19        60
#    television       0.41      0.55      0.47        60
#           bed       0.50      0.10      0.17        60
#         chair       0.38      0.75      0.50        60
#         couch       0.33      0.12      0.17        60
#         table       0.21      0.12      0.15        60
#      wardrobe       0.71      0.73      0.72        60
#           bee       0.20      0.18      0.19        60
#        beetle       0.28      0.33      0.30        60
#     butterfly       0.33      0.32      0.32        60
#   caterpillar       0.25      0.30      0.27        60
#     cockroach       0.39      0.78      0.53        60
#          bear       0.11      0.10      0.10        60
#       leopard       0.21      0.22      0.21        60
#          lion       0.26      0.17      0.20        60
#         tiger       0.18      0.28      0.22        60
#          wolf       0.19      0.18      0.19        60
#        bridge       0.32      0.25      0.28        60
#        castle       0.38      0.60      0.47        60
#         house       0.25      0.22      0.23        60
#          road       0.46      0.78      0.58        60
#    skyscraper       0.64      0.58      0.61        60
#         cloud       0.68      0.38      0.49        60
#        forest       0.34      0.53      0.42        60
#      mountain       0.38      0.35      0.37        60
#         plain       0.54      0.72      0.62        60
#           sea       0.62      0.47      0.53        60
#         camel       0.22      0.10      0.14        60
#        cattle       0.27      0.23      0.25        60
#    chimpanzee       0.35      0.28      0.31        60
#      elephant       0.38      0.25      0.30        60
#      kangaroo       0.10      0.08      0.09        60
#           fox       0.06      0.03      0.04        60
#     porcupine       0.40      0.27      0.32        60
#        possum       0.12      0.10      0.11        60
#       raccoon       0.13      0.15      0.14        60
#         skunk       0.21      0.73      0.33        60
#          crab       0.27      0.18      0.22        60
#       lobster       0.19      0.22      0.20        60
#         snail       0.10      0.05      0.07        60
#        spider       0.28      0.32      0.30        60
#          worm       0.34      0.45      0.39        60
#          baby       0.17      0.12      0.14        60
#           boy       0.25      0.15      0.19        60
#          girl       0.08      0.05      0.06        60
#           man       0.43      0.20      0.27        60
#         woman       0.31      0.15      0.20        60
#     crocodile       0.18      0.10      0.13        60
#      dinosaur       0.30      0.35      0.32        60
#        lizard       0.09      0.08      0.09        60
#         snake       0.25      0.47      0.33        60
#        turtle       0.19      0.13      0.16        60
#       hamster       0.35      0.30      0.32        60
#         mouse       0.13      0.10      0.11        60
#        rabbit       0.14      0.12      0.13        60
#         shrew       0.14      0.17      0.15        60
#      squirrel       0.16      0.08      0.11        60
#    maple tree       0.51      0.33      0.40        60
#      oak tree       0.42      0.70      0.53        60
#     palm tree       0.49      0.37      0.42        60
#     pine tree       0.36      0.42      0.38        60
#   willow tree       0.29      0.10      0.15        60
#       bicycle       0.25      0.43      0.32        60
#           bus       0.17      0.10      0.13        60
#    motorcycle       0.19      0.67      0.30        60
#  pickup truck       0.43      0.45      0.44        60
#         train       0.39      0.30      0.34        60
#    lawn mower       0.45      0.57      0.50        60
#        rocket       0.52      0.58      0.55        60
#     streetcar       0.27      0.17      0.21        60
#          tank       0.39      0.48      0.43        60
#       tractor       0.23      0.32      0.27        60
#
#      accuracy                           0.33      6000
#     macro avg       0.32      0.33      0.31      6000
#  weighted avg       0.32      0.33      0.31      6000
# --- Finished plotting for 75 labeled/class ---
#
# === Running experiment with 175 labeled samples per class ===
#
# [Data Split] Fixed Count: 175 labeled samples per class
# Labeled Training Data: 17500 samples
# Unlabeled Training Data: 30500 samples
# Validation Data: 6000 samples
# Test Data: 6000 samples
# [Epoch Completed] FC=175  Ep[1/20]  TrainLoss: 4.2407 | TrainAcc: 7.77%  SupLoss: 4.2404 | UnsupLoss: 0.0004  ValLoss: 3.5761 | ValAcc: 16.15%
# [Epoch Completed] FC=175  Ep[2/20]  TrainLoss: 2.9687 | TrainAcc: 27.94%  SupLoss: 2.9527 | UnsupLoss: 0.0200  ValLoss: 2.6720 | ValAcc: 32.03%
# [Epoch Completed] FC=175  Ep[3/20]  TrainLoss: 2.0836 | TrainAcc: 46.18%  SupLoss: 2.0469 | UnsupLoss: 0.0458  ValLoss: 2.3134 | ValAcc: 39.75%
# [Epoch Completed] FC=175  Ep[4/20]  TrainLoss: 1.4384 | TrainAcc: 62.59%  SupLoss: 1.3788 | UnsupLoss: 0.0746  ValLoss: 2.1893 | ValAcc: 43.28%
# [Epoch Completed] FC=175  Ep[5/20]  TrainLoss: 0.9553 | TrainAcc: 77.15%  SupLoss: 0.8692 | UnsupLoss: 0.1076  ValLoss: 2.2019 | ValAcc: 44.42%
# [Epoch Completed] FC=175  Ep[6/20]  TrainLoss: 0.6052 | TrainAcc: 88.71%  SupLoss: 0.4940 | UnsupLoss: 0.1390  ValLoss: 2.2112 | ValAcc: 45.67%
# [Epoch Completed] FC=175  Ep[7/20]  TrainLoss: 0.3905 | TrainAcc: 95.27%  SupLoss: 0.2726 | UnsupLoss: 0.1474  ValLoss: 2.2421 | ValAcc: 46.50%
# [Epoch Completed] FC=175  Ep[8/20]  TrainLoss: 0.3092 | TrainAcc: 97.73%  SupLoss: 0.1720 | UnsupLoss: 0.1715  ValLoss: 2.2540 | ValAcc: 46.82%
# [Epoch Completed] FC=175  Ep[9/20]  TrainLoss: 0.2611 | TrainAcc: 98.80%  SupLoss: 0.1159 | UnsupLoss: 0.1815  ValLoss: 2.2919 | ValAcc: 47.28%
# [Epoch Completed] FC=175  Ep[10/20]  TrainLoss: 0.2356 | TrainAcc: 99.29%  SupLoss: 0.0898 | UnsupLoss: 0.1822  ValLoss: 2.2801 | ValAcc: 48.08%
# [Epoch Completed] FC=175  Ep[11/20]  TrainLoss: 0.2126 | TrainAcc: 99.63%  SupLoss: 0.0669 | UnsupLoss: 0.1820  ValLoss: 2.3126 | ValAcc: 48.57%
# [Epoch Completed] FC=175  Ep[12/20]  TrainLoss: 0.2048 | TrainAcc: 99.74%  SupLoss: 0.0528 | UnsupLoss: 0.1899  ValLoss: 2.3265 | ValAcc: 47.95%
# [Epoch Completed] FC=175  Ep[13/20]  TrainLoss: 0.1783 | TrainAcc: 99.89%  SupLoss: 0.0427 | UnsupLoss: 0.1694  ValLoss: 2.3164 | ValAcc: 48.53%
# [Epoch Completed] FC=175  Ep[14/20]  TrainLoss: 0.1729 | TrainAcc: 99.93%  SupLoss: 0.0367 | UnsupLoss: 0.1703  ValLoss: 2.2799 | ValAcc: 49.08%
# [Epoch Completed] FC=175  Ep[15/20]  TrainLoss: 0.1568 | TrainAcc: 99.96%  SupLoss: 0.0308 | UnsupLoss: 0.1575  ValLoss: 2.2910 | ValAcc: 49.55%
# [Epoch Completed] FC=175  Ep[16/20]  TrainLoss: 0.1532 | TrainAcc: 99.98%  SupLoss: 0.0260 | UnsupLoss: 0.1590  ValLoss: 2.2720 | ValAcc: 50.17%
# [Epoch Completed] FC=175  Ep[17/20]  TrainLoss: 0.1424 | TrainAcc: 99.98%  SupLoss: 0.0243 | UnsupLoss: 0.1477  ValLoss: 2.2809 | ValAcc: 49.53%
# [Epoch Completed] FC=175  Ep[18/20]  TrainLoss: 0.1415 | TrainAcc: 99.99%  SupLoss: 0.0222 | UnsupLoss: 0.1491  ValLoss: 2.2731 | ValAcc: 49.75%
# [Epoch Completed] FC=175  Ep[19/20]  TrainLoss: 0.1467 | TrainAcc: 99.99%  SupLoss: 0.0210 | UnsupLoss: 0.1571  ValLoss: 2.2602 | ValAcc: 49.90%
# [Epoch Completed] FC=175  Ep[20/20]  TrainLoss: 0.1520 | TrainAcc: 99.99%  SupLoss: 0.0210 | UnsupLoss: 0.1637  ValLoss: 2.2755 | ValAcc: 49.90%
#
# [Test Evaluation] FC=175  Test Accuracy: 50.47% | ROC AUC: 0.9611 | AvgPrecision: 0.5273
#                precision    recall  f1-score   support
#
#        beaver       0.22      0.17      0.19        60
#       dolphin       0.52      0.57      0.54        60
#         otter       0.24      0.13      0.17        60
#          seal       0.24      0.15      0.18        60
#         whale       0.45      0.72      0.55        60
# aquarium fish       0.58      0.62      0.60        60
#      flatfish       0.55      0.28      0.37        60
#           ray       0.54      0.37      0.44        60
#         shark       0.55      0.45      0.50        60
#         trout       0.70      0.65      0.67        60
#        orchid       0.64      0.62      0.63        60
#         poppy       0.62      0.55      0.58        60
#          rose       0.58      0.47      0.52        60
#     sunflower       0.71      0.80      0.75        60
#         tulip       0.44      0.33      0.38        60
#        bottle       0.69      0.73      0.71        60
#          bowl       0.42      0.38      0.40        60
#           can       0.65      0.50      0.57        60
#           cup       0.71      0.67      0.69        60
#         plate       0.58      0.57      0.57        60
#         apple       0.85      0.73      0.79        60
#      mushroom       0.40      0.60      0.48        60
#        orange       0.65      0.85      0.74        60
#          pear       0.57      0.65      0.60        60
#  sweet pepper       0.41      0.53      0.46        60
#         clock       0.46      0.43      0.45        60
#      keyboard       0.74      0.80      0.77        60
#          lamp       0.62      0.43      0.51        60
#     telephone       0.52      0.53      0.52        60
#    television       0.56      0.52      0.54        60
#           bed       0.56      0.60      0.58        60
#         chair       0.68      0.87      0.76        60
#         couch       0.47      0.30      0.37        60
#         table       0.54      0.32      0.40        60
#      wardrobe       0.79      0.80      0.79        60
#           bee       0.33      0.52      0.40        60
#        beetle       0.31      0.43      0.36        60
#     butterfly       0.45      0.45      0.45        60
#   caterpillar       0.48      0.52      0.50        60
#     cockroach       0.57      0.72      0.63        60
#          bear       0.22      0.20      0.21        60
#       leopard       0.39      0.53      0.45        60
#          lion       0.62      0.40      0.48        60
#         tiger       0.53      0.40      0.46        60
#          wolf       0.33      0.43      0.38        60
#        bridge       0.55      0.48      0.51        60
#        castle       0.58      0.62      0.60        60
#         house       0.49      0.48      0.49        60
#          road       0.77      0.82      0.79        60
#    skyscraper       0.82      0.75      0.78        60
#         cloud       0.67      0.55      0.61        60
#        forest       0.52      0.48      0.50        60
#      mountain       0.61      0.67      0.63        60
#         plain       0.69      0.77      0.72        60
#           sea       0.72      0.65      0.68        60
#         camel       0.57      0.35      0.43        60
#        cattle       0.43      0.48      0.46        60
#    chimpanzee       0.55      0.62      0.58        60
#      elephant       0.49      0.57      0.53        60
#      kangaroo       0.24      0.27      0.25        60
#           fox       0.42      0.37      0.39        60
#     porcupine       0.59      0.43      0.50        60
#        possum       0.40      0.27      0.32        60
#       raccoon       0.48      0.52      0.50        60
#         skunk       0.49      0.75      0.59        60
#          crab       0.37      0.43      0.40        60
#       lobster       0.40      0.32      0.36        60
#         snail       0.40      0.38      0.39        60
#        spider       0.45      0.58      0.51        60
#          worm       0.58      0.65      0.61        60
#          baby       0.52      0.25      0.34        60
#           boy       0.36      0.33      0.34        60
#          girl       0.25      0.17      0.20        60
#           man       0.29      0.33      0.31        60
#         woman       0.21      0.18      0.19        60
#     crocodile       0.39      0.37      0.38        60
#      dinosaur       0.48      0.53      0.50        60
#        lizard       0.35      0.38      0.37        60
#         snake       0.41      0.48      0.45        60
#        turtle       0.38      0.33      0.36        60
#       hamster       0.69      0.57      0.62        60
#         mouse       0.30      0.17      0.22        60
#        rabbit       0.44      0.27      0.33        60
#         shrew       0.27      0.38      0.32        60
#      squirrel       0.21      0.13      0.16        60
#    maple tree       0.66      0.45      0.53        60
#      oak tree       0.56      0.80      0.66        60
#     palm tree       0.57      0.72      0.63        60
#     pine tree       0.55      0.45      0.50        60
#   willow tree       0.65      0.33      0.44        60
#       bicycle       0.51      0.63      0.57        60
#           bus       0.53      0.50      0.51        60
#    motorcycle       0.42      0.87      0.57        60
#  pickup truck       0.56      0.62      0.59        60
#         train       0.48      0.57      0.52        60
#    lawn mower       0.60      0.67      0.63        60
#        rocket       0.63      0.73      0.68        60
#     streetcar       0.64      0.48      0.55        60
#          tank       0.48      0.73      0.58        60
#       tractor       0.40      0.50      0.44        60
#
#      accuracy                           0.50      6000
#     macro avg       0.51      0.50      0.50      6000
#  weighted avg       0.51      0.50      0.50      6000
# --- Finished plotting for 175 labeled/class ---
#
# === Running experiment with 260 labeled samples per class ===
#
# [Data Split] Fixed Count: 260 labeled samples per class
# Labeled Training Data: 26000 samples
# Unlabeled Training Data: 22000 samples
# Validation Data: 6000 samples
# Test Data: 6000 samples
# [Epoch Completed] FC=260  Ep[1/20]  TrainLoss: 3.8700 | TrainAcc: 13.55%  SupLoss: 3.8656 | UnsupLoss: 0.0056  ValLoss: 2.9998 | ValAcc: 25.43%
# [Epoch Completed] FC=260  Ep[2/20]  TrainLoss: 2.3874 | TrainAcc: 38.63%  SupLoss: 2.3546 | UnsupLoss: 0.0410  ValLoss: 2.2456 | ValAcc: 40.53%
# [Epoch Completed] FC=260  Ep[3/20]  TrainLoss: 1.6547 | TrainAcc: 55.74%  SupLoss: 1.5846 | UnsupLoss: 0.0876  ValLoss: 2.0190 | ValAcc: 46.73%
# [Epoch Completed] FC=260  Ep[4/20]  TrainLoss: 1.1659 | TrainAcc: 69.63%  SupLoss: 1.0705 | UnsupLoss: 0.1192  ValLoss: 1.9376 | ValAcc: 49.75%
# [Epoch Completed] FC=260  Ep[5/20]  TrainLoss: 0.8169 | TrainAcc: 80.38%  SupLoss: 0.6956 | UnsupLoss: 0.1516  ValLoss: 1.9043 | ValAcc: 51.08%
# [Epoch Completed] FC=260  Ep[6/20]  TrainLoss: 0.5713 | TrainAcc: 88.90%  SupLoss: 0.4272 | UnsupLoss: 0.1801  ValLoss: 1.9079 | ValAcc: 52.50%
# [Epoch Completed] FC=260  Ep[7/20]  TrainLoss: 0.4162 | TrainAcc: 94.38%  SupLoss: 0.2598 | UnsupLoss: 0.1955  ValLoss: 1.9465 | ValAcc: 53.00%
# [Epoch Completed] FC=260  Ep[8/20]  TrainLoss: 0.3397 | TrainAcc: 96.85%  SupLoss: 0.1714 | UnsupLoss: 0.2104  ValLoss: 1.9770 | ValAcc: 53.35%
# [Epoch Completed] FC=260  Ep[9/20]  TrainLoss: 0.2829 | TrainAcc: 98.10%  SupLoss: 0.1215 | UnsupLoss: 0.2018  ValLoss: 1.9520 | ValAcc: 54.58%
# [Epoch Completed] FC=260  Ep[10/20]  TrainLoss: 0.2531 | TrainAcc: 98.80%  SupLoss: 0.0902 | UnsupLoss: 0.2036  ValLoss: 1.9860 | ValAcc: 55.20%
# [Epoch Completed] FC=260  Ep[11/20]  TrainLoss: 0.2276 | TrainAcc: 99.32%  SupLoss: 0.0662 | UnsupLoss: 0.2017  ValLoss: 1.9734 | ValAcc: 55.35%
# [Epoch Completed] FC=260  Ep[12/20]  TrainLoss: 0.1982 | TrainAcc: 99.70%  SupLoss: 0.0501 | UnsupLoss: 0.1852  ValLoss: 1.9999 | ValAcc: 54.87%
# [Epoch Completed] FC=260  Ep[13/20]  TrainLoss: 0.1781 | TrainAcc: 99.84%  SupLoss: 0.0379 | UnsupLoss: 0.1752  ValLoss: 1.9821 | ValAcc: 55.48%
# [Epoch Completed] FC=260  Ep[14/20]  TrainLoss: 0.1602 | TrainAcc: 99.93%  SupLoss: 0.0307 | UnsupLoss: 0.1619  ValLoss: 1.9809 | ValAcc: 56.03%
# [Epoch Completed] FC=260  Ep[15/20]  TrainLoss: 0.1527 | TrainAcc: 99.97%  SupLoss: 0.0255 | UnsupLoss: 0.1590  ValLoss: 1.9776 | ValAcc: 56.00%
# [Epoch Completed] FC=260  Ep[16/20]  TrainLoss: 0.1439 | TrainAcc: 99.98%  SupLoss: 0.0221 | UnsupLoss: 0.1522  ValLoss: 1.9737 | ValAcc: 55.98%
# [Epoch Completed] FC=260  Ep[17/20]  TrainLoss: 0.1338 | TrainAcc: 99.98%  SupLoss: 0.0196 | UnsupLoss: 0.1427  ValLoss: 1.9634 | ValAcc: 56.38%
# [Epoch Completed] FC=260  Ep[18/20]  TrainLoss: 0.1279 | TrainAcc: 100.00%  SupLoss: 0.0180 | UnsupLoss: 0.1373  ValLoss: 1.9597 | ValAcc: 56.42%
# [Epoch Completed] FC=260  Ep[19/20]  TrainLoss: 0.1215 | TrainAcc: 99.99%  SupLoss: 0.0168 | UnsupLoss: 0.1308  ValLoss: 1.9593 | ValAcc: 56.22%
# [Epoch Completed] FC=260  Ep[20/20]  TrainLoss: 0.1264 | TrainAcc: 100.00%  SupLoss: 0.0165 | UnsupLoss: 0.1374  ValLoss: 1.9623 | ValAcc: 56.50%
#
# [Test Evaluation] FC=260  Test Accuracy: 57.50% | ROC AUC: 0.9742 | AvgPrecision: 0.6181
#                precision    recall  f1-score   support
#
#        beaver       0.33      0.30      0.32        60
#       dolphin       0.59      0.60      0.60        60
#         otter       0.33      0.25      0.28        60
#          seal       0.31      0.18      0.23        60
#         whale       0.53      0.78      0.64        60
# aquarium fish       0.75      0.60      0.67        60
#      flatfish       0.56      0.32      0.40        60
#           ray       0.74      0.47      0.57        60
#         shark       0.64      0.45      0.53        60
#         trout       0.68      0.72      0.70        60
#        orchid       0.70      0.58      0.64        60
#         poppy       0.65      0.72      0.68        60
#          rose       0.67      0.57      0.61        60
#     sunflower       0.82      0.82      0.82        60
#         tulip       0.42      0.42      0.42        60
#        bottle       0.76      0.75      0.76        60
#          bowl       0.58      0.53      0.56        60
#           can       0.53      0.65      0.58        60
#           cup       0.79      0.77      0.78        60
#         plate       0.66      0.68      0.67        60
#         apple       0.84      0.77      0.80        60
#      mushroom       0.47      0.57      0.51        60
#        orange       0.72      0.92      0.81        60
#          pear       0.65      0.57      0.61        60
#  sweet pepper       0.55      0.48      0.51        60
#         clock       0.57      0.60      0.59        60
#      keyboard       0.71      0.83      0.77        60
#          lamp       0.67      0.48      0.56        60
#     telephone       0.69      0.57      0.62        60
#    television       0.64      0.62      0.63        60
#           bed       0.68      0.60      0.64        60
#         chair       0.72      0.92      0.81        60
#         couch       0.45      0.37      0.40        60
#         table       0.62      0.42      0.50        60
#      wardrobe       0.84      0.78      0.81        60
#           bee       0.45      0.67      0.54        60
#        beetle       0.39      0.47      0.42        60
#     butterfly       0.51      0.62      0.56        60
#   caterpillar       0.52      0.53      0.53        60
#     cockroach       0.60      0.77      0.67        60
#          bear       0.41      0.33      0.37        60
#       leopard       0.43      0.72      0.54        60
#          lion       0.66      0.72      0.69        60
#         tiger       0.56      0.72      0.63        60
#          wolf       0.52      0.52      0.52        60
#        bridge       0.60      0.45      0.51        60
#        castle       0.64      0.80      0.71        60
#         house       0.54      0.48      0.51        60
#          road       0.80      0.82      0.81        60
#    skyscraper       0.89      0.68      0.77        60
#         cloud       0.83      0.65      0.73        60
#        forest       0.57      0.62      0.59        60
#      mountain       0.67      0.73      0.70        60
#         plain       0.78      0.77      0.77        60
#           sea       0.69      0.78      0.73        60
#         camel       0.51      0.42      0.46        60
#        cattle       0.50      0.58      0.54        60
#    chimpanzee       0.63      0.62      0.62        60
#      elephant       0.60      0.57      0.58        60
#      kangaroo       0.34      0.30      0.32        60
#           fox       0.53      0.47      0.50        60
#     porcupine       0.57      0.42      0.48        60
#        possum       0.39      0.37      0.38        60
#       raccoon       0.47      0.52      0.49        60
#         skunk       0.67      0.80      0.73        60
#          crab       0.40      0.48      0.44        60
#       lobster       0.41      0.35      0.38        60
#         snail       0.61      0.52      0.56        60
#        spider       0.51      0.70      0.59        60
#          worm       0.70      0.67      0.68        60
#          baby       0.54      0.35      0.42        60
#           boy       0.27      0.30      0.28        60
#          girl       0.43      0.27      0.33        60
#           man       0.48      0.35      0.40        60
#         woman       0.42      0.42      0.42        60
#     crocodile       0.52      0.48      0.50        60
#      dinosaur       0.52      0.63      0.57        60
#        lizard       0.22      0.28      0.25        60
#         snake       0.47      0.62      0.53        60
#        turtle       0.37      0.43      0.40        60
#       hamster       0.81      0.70      0.75        60
#         mouse       0.48      0.35      0.40        60
#        rabbit       0.56      0.47      0.51        60
#         shrew       0.35      0.47      0.40        60
#      squirrel       0.30      0.13      0.18        60
#    maple tree       0.76      0.47      0.58        60
#      oak tree       0.59      0.82      0.69        60
#     palm tree       0.71      0.87      0.78        60
#     pine tree       0.65      0.55      0.59        60
#   willow tree       0.67      0.43      0.53        60
#       bicycle       0.52      0.72      0.60        60
#           bus       0.51      0.47      0.49        60
#    motorcycle       0.50      0.93      0.65        60
#  pickup truck       0.72      0.80      0.76        60
#         train       0.62      0.65      0.63        60
#    lawn mower       0.67      0.72      0.69        60
#        rocket       0.75      0.73      0.74        60
#     streetcar       0.59      0.50      0.54        60
#          tank       0.63      0.68      0.66        60
#       tractor       0.56      0.68      0.62        60
#
#      accuracy                           0.57      6000
#     macro avg       0.58      0.57      0.57      6000
#  weighted avg       0.58      0.57      0.57      6000
# --- Finished plotting for 260 labeled/class ---
#
# === Running experiment with 360 labeled samples per class ===
#
# [Data Split] Fixed Count: 360 labeled samples per class
# Labeled Training Data: 36000 samples
# Unlabeled Training Data: 12000 samples
# Validation Data: 6000 samples
# Test Data: 6000 samples
# [Epoch Completed] FC=360  Ep[1/20]  TrainLoss: 3.5342 | TrainAcc: 19.00%  SupLoss: 3.5258 | UnsupLoss: 0.0104  ValLoss: 2.4378 | ValAcc: 36.48%
# [Epoch Completed] FC=360  Ep[2/20]  TrainLoss: 1.8381 | TrainAcc: 51.16%  SupLoss: 1.7745 | UnsupLoss: 0.0794  ValLoss: 1.6281 | ValAcc: 54.63%
# [Epoch Completed] FC=360  Ep[3/20]  TrainLoss: 1.2271 | TrainAcc: 67.25%  SupLoss: 1.1208 | UnsupLoss: 0.1328  ValLoss: 1.4866 | ValAcc: 59.07%
# [Epoch Completed] FC=360  Ep[4/20]  TrainLoss: 0.8525 | TrainAcc: 78.27%  SupLoss: 0.7265 | UnsupLoss: 0.1575  ValLoss: 1.3728 | ValAcc: 62.48%
# [Epoch Completed] FC=360  Ep[5/20]  TrainLoss: 0.6076 | TrainAcc: 86.41%  SupLoss: 0.4639 | UnsupLoss: 0.1797  ValLoss: 1.3616 | ValAcc: 64.03%
# [Epoch Completed] FC=360  Ep[6/20]  TrainLoss: 0.4429 | TrainAcc: 92.01%  SupLoss: 0.2903 | UnsupLoss: 0.1907  ValLoss: 1.3797 | ValAcc: 64.72%
# [Epoch Completed] FC=360  Ep[7/20]  TrainLoss: 0.3359 | TrainAcc: 95.39%  SupLoss: 0.1841 | UnsupLoss: 0.1897  ValLoss: 1.4074 | ValAcc: 65.17%
# [Epoch Completed] FC=360  Ep[8/20]  TrainLoss: 0.2784 | TrainAcc: 97.15%  SupLoss: 0.1268 | UnsupLoss: 0.1895  ValLoss: 1.3671 | ValAcc: 66.02%
# [Epoch Completed] FC=360  Ep[9/20]  TrainLoss: 0.2226 | TrainAcc: 98.56%  SupLoss: 0.0843 | UnsupLoss: 0.1729  ValLoss: 1.4034 | ValAcc: 66.07%
# [Epoch Completed] FC=360  Ep[10/20]  TrainLoss: 0.1895 | TrainAcc: 99.11%  SupLoss: 0.0601 | UnsupLoss: 0.1617  ValLoss: 1.4045 | ValAcc: 66.27%
# [Epoch Completed] FC=360  Ep[11/20]  TrainLoss: 0.1574 | TrainAcc: 99.60%  SupLoss: 0.0433 | UnsupLoss: 0.1426  ValLoss: 1.4094 | ValAcc: 67.08%
# [Epoch Completed] FC=360  Ep[12/20]  TrainLoss: 0.1416 | TrainAcc: 99.77%  SupLoss: 0.0331 | UnsupLoss: 0.1356  ValLoss: 1.4203 | ValAcc: 66.88%
# [Epoch Completed] FC=360  Ep[13/20]  TrainLoss: 0.1173 | TrainAcc: 99.85%  SupLoss: 0.0254 | UnsupLoss: 0.1149  ValLoss: 1.4151 | ValAcc: 67.07%
# [Epoch Completed] FC=360  Ep[14/20]  TrainLoss: 0.1049 | TrainAcc: 99.92%  SupLoss: 0.0200 | UnsupLoss: 0.1061  ValLoss: 1.4057 | ValAcc: 66.80%
# [Epoch Completed] FC=360  Ep[15/20]  TrainLoss: 0.0955 | TrainAcc: 99.95%  SupLoss: 0.0169 | UnsupLoss: 0.0983  ValLoss: 1.4249 | ValAcc: 66.87%
# [Epoch Completed] FC=360  Ep[16/20]  TrainLoss: 0.0904 | TrainAcc: 99.98%  SupLoss: 0.0148 | UnsupLoss: 0.0945  ValLoss: 1.4124 | ValAcc: 67.35%
# [Epoch Completed] FC=360  Ep[17/20]  TrainLoss: 0.0795 | TrainAcc: 99.98%  SupLoss: 0.0131 | UnsupLoss: 0.0831  ValLoss: 1.4105 | ValAcc: 67.42%
# [Epoch Completed] FC=360  Ep[18/20]  TrainLoss: 0.0773 | TrainAcc: 99.98%  SupLoss: 0.0122 | UnsupLoss: 0.0814  ValLoss: 1.4118 | ValAcc: 67.25%
# [Epoch Completed] FC=360  Ep[19/20]  TrainLoss: 0.0750 | TrainAcc: 99.99%  SupLoss: 0.0114 | UnsupLoss: 0.0794  ValLoss: 1.4121 | ValAcc: 67.38%
# [Epoch Completed] FC=360  Ep[20/20]  TrainLoss: 0.0715 | TrainAcc: 99.98%  SupLoss: 0.0112 | UnsupLoss: 0.0754  ValLoss: 1.4065 | ValAcc: 67.48%
#
# [Test Evaluation] FC=360  Test Accuracy: 68.62% | ROC AUC: 0.9866 | AvgPrecision: 0.7488
#                precision    recall  f1-score   support
#
#        beaver       0.58      0.50      0.54        60
#       dolphin       0.53      0.75      0.62        60
#         otter       0.49      0.32      0.38        60
#          seal       0.40      0.42      0.41        60
#         whale       0.68      0.72      0.70        60
# aquarium fish       0.82      0.82      0.82        60
#      flatfish       0.66      0.38      0.48        60
#           ray       0.85      0.57      0.68        60
#         shark       0.64      0.47      0.54        60
#         trout       0.80      0.73      0.77        60
#        orchid       0.87      0.77      0.81        60
#         poppy       0.70      0.72      0.71        60
#          rose       0.70      0.63      0.67        60
#     sunflower       0.92      0.80      0.86        60
#         tulip       0.62      0.55      0.58        60
#        bottle       0.84      0.85      0.84        60
#          bowl       0.62      0.58      0.60        60
#           can       0.67      0.70      0.68        60
#           cup       0.89      0.78      0.83        60
#         plate       0.70      0.83      0.76        60
#         apple       0.88      0.87      0.87        60
#      mushroom       0.56      0.83      0.67        60
#        orange       0.80      0.95      0.87        60
#          pear       0.86      0.70      0.77        60
#  sweet pepper       0.71      0.73      0.72        60
#         clock       0.79      0.68      0.73        60
#      keyboard       0.83      0.88      0.85        60
#          lamp       0.75      0.60      0.67        60
#     telephone       0.76      0.73      0.75        60
#    television       0.84      0.80      0.82        60
#           bed       0.80      0.67      0.73        60
#         chair       0.83      0.97      0.89        60
#         couch       0.73      0.55      0.63        60
#         table       0.62      0.70      0.66        60
#      wardrobe       0.89      0.92      0.90        60
#           bee       0.63      0.65      0.64        60
#        beetle       0.58      0.62      0.60        60
#     butterfly       0.78      0.78      0.78        60
#   caterpillar       0.59      0.70      0.64        60
#     cockroach       0.77      0.85      0.81        60
#          bear       0.50      0.48      0.49        60
#       leopard       0.51      0.68      0.58        60
#          lion       0.82      0.82      0.82        60
#         tiger       0.69      0.68      0.69        60
#          wolf       0.58      0.63      0.61        60
#        bridge       0.68      0.65      0.67        60
#        castle       0.70      0.88      0.78        60
#         house       0.68      0.60      0.64        60
#          road       0.86      0.90      0.88        60
#    skyscraper       0.80      0.85      0.82        60
#         cloud       0.87      0.67      0.75        60
#        forest       0.66      0.68      0.67        60
#      mountain       0.81      0.83      0.82        60
#         plain       0.76      0.78      0.77        60
#           sea       0.75      0.72      0.74        60
#         camel       0.72      0.63      0.67        60
#        cattle       0.60      0.65      0.62        60
#    chimpanzee       0.88      0.77      0.82        60
#      elephant       0.71      0.75      0.73        60
#      kangaroo       0.51      0.45      0.48        60
#           fox       0.64      0.70      0.67        60
#     porcupine       0.71      0.62      0.66        60
#        possum       0.59      0.55      0.57        60
#       raccoon       0.57      0.65      0.61        60
#         skunk       0.76      0.88      0.82        60
#          crab       0.60      0.62      0.61        60
#       lobster       0.59      0.53      0.56        60
#         snail       0.81      0.65      0.72        60
#        spider       0.59      0.77      0.67        60
#          worm       0.80      0.78      0.79        60
#          baby       0.62      0.60      0.61        60
#           boy       0.46      0.43      0.44        60
#          girl       0.39      0.42      0.40        60
#           man       0.48      0.47      0.47        60
#         woman       0.44      0.35      0.39        60
#     crocodile       0.51      0.65      0.57        60
#      dinosaur       0.69      0.72      0.70        60
#        lizard       0.50      0.53      0.52        60
#         snake       0.71      0.73      0.72        60
#        turtle       0.64      0.70      0.67        60
#       hamster       0.84      0.72      0.77        60
#         mouse       0.65      0.47      0.54        60
#        rabbit       0.62      0.50      0.56        60
#         shrew       0.49      0.55      0.52        60
#      squirrel       0.46      0.38      0.42        60
#    maple tree       0.79      0.55      0.65        60
#      oak tree       0.57      0.88      0.69        60
#     palm tree       0.85      0.88      0.87        60
#     pine tree       0.74      0.72      0.73        60
#   willow tree       0.67      0.37      0.47        60
#       bicycle       0.77      0.90      0.83        60
#           bus       0.62      0.65      0.63        60
#    motorcycle       0.73      0.98      0.84        60
#  pickup truck       0.81      0.83      0.82        60
#         train       0.72      0.82      0.77        60
#    lawn mower       0.80      0.87      0.83        60
#        rocket       0.79      0.75      0.77        60
#     streetcar       0.66      0.68      0.67        60
#          tank       0.73      0.75      0.74        60
#       tractor       0.60      0.83      0.70        60
#
#      accuracy                           0.69      6000
#     macro avg       0.69      0.69      0.68      6000
#  weighted avg       0.69      0.69      0.68      6000
# --- Finished plotting for 360 labeled/class ---
#
# [Test Summary] Best run: 360 labeled samples per class with Test Accuracy: 68.62%
